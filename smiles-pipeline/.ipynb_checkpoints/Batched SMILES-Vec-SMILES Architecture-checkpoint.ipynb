# %% [markdown]
# # The Problem Statement:
#
# The sequence identity of the COVID19 protease and that of SARS-CoV is high, hence by using the known SARS-CoV protease drugs generate possible drugs using machine learning methods to generate novel drug like candidates. Use a variational autoencoder with SMILES representation to generate novel molecules from the trained continuous latent space. The novel molecules shall be assessed based on SMART pattern matching, to rule out unlikely molecular structures e.g structures with multiple 3,4,7,8 membered rings, purely acyclic compounds, highly branched ones etc. Furthermore, diversity based on PubChem / MACCS fingerprints (tanimoto coefficients <= 0.60) shall also be assessed to make sure generated structures are significantly dissimilar to training set. Use multiple SARS-CoV-2 protease conformation to screen of generated chemicals using ensemble molecular docking protocol at both allosteric and orthosteric sites. Retain chemicals with best docking scores and binding energies as per the guidelines. Shortlist the top 100 or top 25% (max 100) hits and refine the best 10 using MD simulation without any restraints.

# %%
import pandas as pd
import numpy as np
import random

# %%
random.seed(24)

# %%
from rdkit import Chem, DataStructs
from rdkit.Chem import Draw, Descriptors, AllChem

def canonicalize(smiles):
    return Chem.MolToSmiles(Chem.MolFromSmiles(smiles))

def validSMILES(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return False
    return True

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, matthews_corrcoef
from sklearn.cluster import KMeans

# %%
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.nn.utils.rnn import pad_packed_sequence, pack_padded_sequence#, masked_cross_entropy
#from masked_cross_entropy import *

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
USE_CUDA = False

# %%
traindata = pd.read_csv('data/trainDILI.csv')

# %%
traindata['SMILES']
# Out:
# 0                                        BrC(Cl)C(F)(F)F
# 1                            Br[C@@H](C(C)C)C(=O)NC(=O)N
# 2      Brc1[nH]c2c3c1CC1N(CC(C=C1c3ccc2)C(=O)N[C@]1(O...
# 3        Brc1c(nc(nc1Oc1c(cc(cc1C)C#N)C)Nc1ccc(cc1)C#N)N
# 4                             Brc1c2nccnc2ccc1NC=1NCCN=1
#                              ...
# 961                           s1cccc1CN(CCN(C)C)c1ncccc1
# 962    s1cccc1C\C(=C/c1n(Cc2ccc(cc2)C(O)=O)c(nc1)CCCC...
# 963                               s1cccc1\C=C\C1=NCCCN1C
# 964          s1ccnc1NC(=O)C=1N(S(=O)(=O)c2c(cccc2)C=1O)C
# 965    s1cncc1COC(=O)NC(Cc1ccccc1)C(O)CC(NC(=O)C(NC(=...
# Name: SMILES, Length: 966, dtype: object

# %%
traindata['cleanSMILES'] = traindata['SMILES'].apply(canonicalize)

# %%
traindata
# Out:
#                                                 SMILES      Drug_Name  IsDILI  \
# 0                                      BrC(Cl)C(F)(F)F      Halothane     1.0
# 1                          Br[C@@H](C(C)C)C(=O)NC(=O)N     Bromisoval     1.0
# 2    Brc1[nH]c2c3c1CC1N(CC(C=C1c3ccc2)C(=O)N[C@]1(O...  Bromocriptine     0.0
# 3      Brc1c(nc(nc1Oc1c(cc(cc1C)C#N)C)Nc1ccc(cc1)C#N)N     Etravirine     1.0
# 4                           Brc1c2nccnc2ccc1NC=1NCCN=1    Brimonidine     0.0
# ..                                                 ...            ...     ...
# 961                         s1cccc1CN(CCN(C)C)c1ncccc1  Methapyrilene     1.0
# 962  s1cccc1C\C(=C/c1n(Cc2ccc(cc2)C(O)=O)c(nc1)CCCC...     Eprosartan     0.0
# 963                             s1cccc1\C=C\C1=NCCCN1C       Pyrantel     0.0
# 964        s1ccnc1NC(=O)C=1N(S(=O)(=O)c2c(cccc2)C=1O)C      Sudoxicam     1.0
# 965  s1cncc1COC(=O)NC(Cc1ccccc1)C(O)CC(NC(=O)C(NC(=...      Ritonavir     1.0
#
#                                            cleanSMILES
# 0                                      FC(F)(F)C(Cl)Br
# 1                           CC(C)[C@H](Br)C(=O)NC(N)=O
# 2    CC(C)CC1C(=O)N2CCCC2[C@@]2(O)O[C@@](NC(=O)C3C=...
# 3      Cc1cc(C#N)cc(C)c1Oc1nc(Nc2ccc(C#N)cc2)nc(N)c1Br
# 4                          Brc1c(NC2=NCCN2)ccc2nccnc12
# ..                                                 ...
# 961                         CN(C)CCN(Cc1cccs1)c1ccccn1
# 962  CCCCc1ncc(/C=C(\Cc2cccs2)C(=O)O)n1Cc1ccc(C(=O)...
# 963                             CN1CCCN=C1/C=C/c1cccs1
# 964           CN1C(C(=O)Nc2nccs2)=C(O)c2ccccc2S1(=O)=O
# 965  CC(C)c1nc(CN(C)C(=O)NC(C(=O)NC(Cc2ccccc2)CC(O)...
#
# [966 rows x 4 columns]

# %%
data = list(zip(traindata['SMILES'],traindata['cleanSMILES']))
identitydata = list(zip(traindata['cleanSMILES'],traindata['cleanSMILES']))

# %%
identitydata
# Out:
# [('FC(F)(F)C(Cl)Br', 'FC(F)(F)C(Cl)Br'),
#  ('CC(C)[C@H](Br)C(=O)NC(N)=O', 'CC(C)[C@H](Br)C(=O)NC(N)=O'),
#  ('CC(C)CC1C(=O)N2CCCC2[C@@]2(O)O[C@@](NC(=O)C3C=C4c5cccc6[nH]c(Br)c(c56)CC4N(C)C3)(C(C)C)C(=O)N12',
#   'CC(C)CC1C(=O)N2CCCC2[C@@]2(O)O[C@@](NC(=O)C3C=C4c5cccc6[nH]c(Br)c(c56)CC4N(C)C3)(C(C)C)C(=O)N12'),
#  ('Cc1cc(C#N)cc(C)c1Oc1nc(Nc2ccc(C#N)cc2)nc(N)c1Br',
#   'Cc1cc(C#N)cc(C)c1Oc1nc(Nc2ccc(C#N)cc2)nc(N)c1Br'),
#  ('Brc1c(NC2=NCCN2)ccc2nccnc12', 'Brc1c(NC2=NCCN2)ccc2nccnc12'),
#  ('Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21',
#   'Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21'),
#  ('CCc1oc2ccccc2c1C(=O)c1cc(Br)c(O)c(Br)c1',
#   'CCc1oc2ccccc2c1C(=O)c1cc(Br)c(O)c(Br)c1'),
#  ('NC(N)=Nc1nc(CSCC/N=C/NS(=O)(=O)c2ccc(Br)cc2)cs1',
#   'NC(N)=Nc1nc(CSCC/N=C/NS(=O)(=O)c2ccc(Br)cc2)cs1'),
#  ('Nc1c(CC(=O)O)cccc1C(=O)c1ccc(Br)cc1',
#   'Nc1c(CC(=O)O)cccc1C(=O)c1ccc(Br)cc1'),
#  ('CN(C)CCC(c1ccc(Br)cc1)c1ccccn1', 'CN(C)CCC(c1ccc(Br)cc1)c1ccccn1'),
#  ('Brc1ccccc1', 'Brc1ccccc1'),
#  ('CCCC1CC(C(=O)NC(C(C)Cl)C2OC(SC)C(O)C(O)C2O)N(C)C1',
#   'CCCC1CC(C(=O)NC(C(C)Cl)C2OC(SC)C(O)C(O)C2O)N(C)C1'),
#  ('O=P(O)(O)C(Cl)(Cl)P(=O)(O)O', 'O=P(O)(O)C(Cl)(Cl)P(=O)(O)O'),
#  ('O=C(NC(CO)C(O)c1ccc([N+](=O)[O-])cc1)C(Cl)Cl',
#   'O=C(NC(CO)C(O)c1ccc([N+](=O)[O-])cc1)C(Cl)Cl'),
#  ('CCCCCCCCCCCCCCCC(=O)OCC(NC(=O)C(Cl)Cl)C(O)c1ccc([N+](=O)[O-])cc1',
#   'CCCCCCCCCCCCCCCC(=O)OCC(NC(=O)C(Cl)Cl)C(O)c1ccc([N+](=O)[O-])cc1'),
#  ('COC(F)(F)C(Cl)Cl', 'COC(F)(F)C(Cl)Cl'),
#  ('FC(F)OC(F)(F)C(F)Cl', 'FC(F)OC(F)(F)C(F)Cl'),
#  ('FC(F)OC(Cl)C(F)(F)F', 'FC(F)OC(Cl)C(F)(F)F'),
#  ('CC(C)(Oc1ccc(C2CC2(Cl)Cl)cc1)C(=O)O',
#   'CC(C)(Oc1ccc(C2CC2(Cl)Cl)cc1)C(=O)O'),
#  ('NC(C(=O)O)C1CC(Cl)=NO1', 'NC(C(=O)O)C1CC(Cl)=NO1'),
#  ('ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl', 'ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl'),
#  ('CC(=O)[C@@]1(O)CCC2C3C=C(Cl)C4=CC(=O)C5CC5[C@]4(C)C3CC[C@@]21C',
#   'CC(=O)[C@@]1(O)CCC2C3C=C(Cl)C4=CC(=O)C5CC5[C@]4(C)C3CC[C@@]21C'),
#  ('CC(=O)O[C@]1(C(C)=O)CCC2C3C=C(Cl)C4=CC(=O)C5CC5[C@]4(C)C3CC[C@@]21C',
#   'CC(=O)O[C@]1(C(C)=O)CCC2C3C=C(Cl)C4=CC(=O)C5CC5[C@]4(C)C3CC[C@@]21C'),
#  ('CCCN(CCC)C(=O)Cc1c(-c2ccc(Cl)cc2)nc2ccc(Cl)cn12',
#   'CCCN(CCC)C(=O)Cc1c(-c2ccc(Cl)cc2)nc2ccc(Cl)cn12'),
#  ('NC(C(=O)NC1C(=O)N2C(C(=O)O)=C(Cl)CCC12)c1ccccc1',
#   'NC(C(=O)NC1C(=O)N2C(C(=O)O)=C(Cl)CCC12)c1ccccc1'),
#  ('CC1(C)OC2CC3C4CCC5=CC(=O)CC[C@]5(C)[C@@]4(F)C(O)C[C@]3(C)[C@]2(C(=O)CCl)O1',
#   'CC1(C)OC2CC3C4CCC5=CC(=O)CC[C@]5(C)[C@@]4(F)C(O)C[C@]3(C)[C@]2(C(=O)CCl)O1'),
#  ('C[C@H]1C[C@@H]2[C@H]3CCC4=CC(=O)C=C[C@]4(C)[C@@]3(F)[C@@H](O)C[C@]2(C)[C@@]1(O)C(=O)CCl',
#   'C[C@H]1C[C@@H]2[C@H]3CCC4=CC(=O)C=C[C@]4(C)[C@@]3(F)[C@@H](O)C[C@]2(C)[C@@]1(O)C(=O)CCl'),
#  ('C[C@H]1C[C@H]2[C@@H]3C[C@H](F)C4=CC(=O)C=C[C@]4(C)[C@@]3(F)[C@@H](O)C[C@]2(C)[C@@]1(O)C(=O)CCl',
#   'C[C@H]1C[C@H]2[C@@H]3C[C@H](F)C4=CC(=O)C=C[C@]4(C)[C@@]3(F)[C@@H](O)C[C@]2(C)[C@@]1(O)C(=O)CCl'),
#  ('CN(CCCl)CCCl', 'CN(CCCl)CCCl'),
#  ('C[C@]12CCC3c4ccc(OC(=O)N(CCCl)CCCl)cc4CCC3C1CCC2O',
#   'C[C@]12CCC3c4ccc(OC(=O)N(CCCl)CCCl)cc4CCC3C1CCC2O'),
#  ('O=c1[nH]cc(N(CCCl)CCCl)c(=O)[nH]1', 'O=c1[nH]cc(N(CCCl)CCCl)c(=O)[nH]1'),
#  ('NC(Cc1ccc(N(CCCl)CCCl)cc1)C(=O)O', 'NC(Cc1ccc(N(CCCl)CCCl)cc1)C(=O)O'),
#  ('O=C(O)CCCc1ccc(N(CCCl)CCCl)cc1', 'O=C(O)CCCc1ccc(N(CCCl)CCCl)cc1'),
#  ('CC(COc1ccccc1)N(CCCl)Cc1ccccc1', 'CC(COc1ccccc1)N(CCCl)Cc1ccccc1'),
#  ('O=NN(CCCl)C(=O)NC1CCCCC1', 'O=NN(CCCl)C(=O)NC1CCCCC1'),
#  ('O=NN(CCCl)C(=O)NCCCl', 'O=NN(CCCl)C(=O)NCCCl'),
#  ('O=P1(N(CCCl)CCCl)NCCCO1', 'O=P1(N(CCCl)CCCl)NCCCO1'),
#  ('O=P1(NCCCl)OCCCN1CCCl', 'O=P1(NCCCl)OCCCN1CCCl'),
#  ('CN(C)CCOc1ccc(/C(=C(/CCCl)c2ccccc2)c2ccccc2)cc1',
#   'CN(C)CCOc1ccc(/C(=C(/CCCl)c2ccccc2)c2ccccc2)cc1'),
#  ('CC1CC2C3CCC4=CC(=O)C=C[C@]4(C)[C@@]3(Cl)C(O)C[C@]2(C)[C@@]1(O)C(=O)CCl',
#   'CC1CC2C3CCC4=CC(=O)C=C[C@]4(C)[C@@]3(Cl)C(O)C[C@]2(C)[C@@]1(O)C(=O)CCl'),
#  ('CC1CC2C3CCC4=CC(=O)C=C[C@]4(C)[C@@]3(Cl)C(O)C[C@]2(C)[C@@]1(O)C(=O)CO',
#   'CC1CC2C3CCC4=CC(=O)C=C[C@]4(C)[C@@]3(Cl)C(O)C[C@]2(C)[C@@]1(O)C(=O)CO'),
#  ('CCC(=O)OCC(=O)[C@@]1(OC(=O)CC)C(C)CC2C3CCC4=CC(=O)C=C[C@]4(C)[C@@]3(Cl)C(O)C[C@@]21C',
#   'CCC(=O)OCC(=O)[C@@]1(OC(=O)CC)C(C)CC2C3CCC4=CC(=O)C=C[C@]4(C)[C@@]3(Cl)C(O)C[C@@]21C'),
#  ('CC1CC2C3CCC4=CC(=O)C=C[C@]4(C)[C@@]3(Cl)C(O)C[C@]2(C)[C@@]1(OC(=O)c1ccco1)C(=O)CCl',
#   'CC1CC2C3CCC4=CC(=O)C=C[C@]4(C)[C@@]3(Cl)C(O)C[C@]2(C)[C@@]1(OC(=O)c1ccco1)C(=O)CCl'),
#  ('C[C@H]1C[C@@H]2[C@H]3[C@H]([C@@H](O)C[C@@]2(C)[C@@]1(O)C(=O)CO)[C@]1(C)C=CC(=O)C=C1C[C@H]3Cl',
#   'C[C@H]1C[C@@H]2[C@H]3[C@H]([C@@H](O)C[C@@]2(C)[C@@]1(O)C(=O)CO)[C@]1(C)C=CC(=O)C=C1C[C@H]3Cl'),
#  ('CC1(C)C(C=C(Cl)Cl)C1C(=O)OCc1cccc(Oc2ccccc2)c1',
#   'CC1(C)C(C=C(Cl)Cl)C1C(=O)OCc1cccc(Oc2ccccc2)c1'),
#  ('ClC=C(Cl)Cl', 'ClC=C(Cl)Cl'),
#  ('C=C(CC)C(=O)c1ccc(OCC(=O)O)c(Cl)c1Cl',
#   'C=C(CC)C(=O)c1ccc(OCC(=O)O)c(Cl)c1Cl'),
#  ('O=C(O)COc1ccc(C(=O)c2cccs2)c(Cl)c1Cl',
#   'O=C(O)COc1ccc(C(=O)c2cccs2)c(Cl)c1Cl'),
#  ('O=C1CCc2ccc(OCCCCN3CCN(c4cccc(Cl)c4Cl)CC3)cc2N1',
#   'O=C1CCc2ccc(OCCCCN3CCN(c4cccc(Cl)c4Cl)CC3)cc2N1'),
#  ('N#Cc1cc(NC(=O)C(=O)O)c(Cl)c(NC(=O)C(=O)O)c1',
#   'N#Cc1cc(NC(=O)C(=O)O)c(Cl)c(NC(=O)C(=O)O)c1'),
#  ('Cc1ccc(Cl)c(Nc2ccccc2C(=O)O)c1Cl', 'Cc1ccc(Cl)c(Nc2ccccc2C(=O)O)c1Cl'),
#  ('CC1(c2ccccc2)Cc2cc(OCC(=O)O)c(Cl)c(Cl)c2C1=O',
#   'CC1(c2ccccc2)Cc2cc(OCC(=O)O)c(Cl)c(Cl)c2C1=O'),
#  ('Nc1nnc(-c2cccc(Cl)c2Cl)c(N)n1', 'Nc1nnc(-c2cccc(Cl)c2Cl)c(N)n1'),
#  ('CCOC(=O)C1=C(C)NC(C)=C(C(=O)OC)C1c1cccc(Cl)c1Cl',
#   'CCOC(=O)C1=C(C)NC(C)=C(C(=O)OC)C1c1cccc(Cl)c1Cl'),
#  ('Cc1cc2c(cc1CC(=O)c1sccc1S(=O)(=O)Nc1onc(C)c1Cl)OCO2',
#   'Cc1cc2c(cc1CC(=O)c1sccc1S(=O)(=O)Nc1onc(C)c1Cl)OCO2'),
#  ('O=C1CN2Cc3c(ccc(Cl)c3Cl)N=C2N1', 'O=C1CN2Cc3c(ccc(Cl)c3Cl)N=C2N1'),
#  ('COC1=CC(=O)CC(C)[C@]12Oc1c(Cl)c(OC)cc(OC)c1C2=O',
#   'COC1=CC(=O)CC(C)[C@]12Oc1c(Cl)c(OC)cc(OC)c1C2=O'),
#  ('CNC(CC(C)C)C(=O)NC1C(=O)NC(CC(N)=O)C(=O)NC2C(=O)NC3C(=O)NC(C(=O)NC(C(=O)O)c4cc(O)cc(O)c4-c4cc3ccc4O)C(O)c3ccc(c(Cl)c3)Oc3cc2cc(c3OC2OC(CO)C(O)C(O)C2OC2C[C@](C)(N)C(O)C(C)O2)Oc2ccc(cc2Cl)C1O',
#   'CNC(CC(C)C)C(=O)NC1C(=O)NC(CC(N)=O)C(=O)NC2C(=O)NC3C(=O)NC(C(=O)NC(C(=O)O)c4cc(O)cc(O)c4-c4cc3ccc4O)C(O)c3ccc(c(Cl)c3)Oc3cc2cc(c3OC2OC(CO)C(O)C(O)C2OC2C[C@](C)(N)C(O)C(C)O2)Oc2ccc(cc2Cl)C1O'),
#  ('CN(C)C1C(O)=C(C(N)=O)C(=O)[C@@]2(O)C(O)=C3C(=O)c4c(O)ccc(Cl)c4C(O)C3CC12',
#   'CN(C)C1C(O)=C(C(N)=O)C(=O)[C@@]2(O)C(O)=C3C(=O)c4c(O)ccc(Cl)c4C(O)C3CC12'),
#  ('Oc1ccc(C2CNCCc3c2cc(O)c(O)c3Cl)cc1', 'Oc1ccc(C2CNCCc3c2cc(O)c(O)c3Cl)cc1'),
#  ('COc1cc(N)c(Cl)cc1C(=O)NC1CCN(CCCOc2ccc(F)cc2)CC1OC',
#   'COc1cc(N)c(Cl)cc1C(=O)NC1CCN(CCCOc2ccc(F)cc2)CC1OC'),
#  ('CCN(CC)CCNC(=O)c1cc(Cl)c(N)cc1OC', 'CCN(CC)CCNC(=O)c1cc(Cl)c(N)cc1OC'),
#  ('COc1ccc(Cl)cc1C(=O)NCCc1ccc(S(=O)(=O)NC(=O)NC2CCCCC2)cc1',
#   'COc1ccc(Cl)cc1C(=O)NCCc1ccc(S(=O)(=O)NC(=O)NC2CCCCC2)cc1'),
#  ('Oc1c(Cl)cc(Cl)cc1Sc1cc(Cl)cc(Cl)c1O',
#   'Oc1c(Cl)cc(Cl)cc1Sc1cc(Cl)cc(Cl)c1O'),
#  ('Clc1ccc(COC(Cn2ccnc2)c2ccc(Cl)cc2Cl)cc1',
#   'Clc1ccc(COC(Cn2ccnc2)c2ccc(Cl)cc2Cl)cc1'),
#  ('Clc1ccc(COC(Cn2ccnc2)c2ccc(Cl)cc2Cl)c(Cl)c1',
#   'Clc1ccc(COC(Cn2ccnc2)c2ccc(Cl)cc2Cl)c(Cl)c1'),
#  ('Clc1ccc(CSC(Cn2ccnc2)c2ccc(Cl)cc2Cl)cc1',
#   'Clc1ccc(CSC(Cn2ccnc2)c2ccc(Cl)cc2Cl)cc1'),
#  ('CC(=O)N1CCN(c2ccc(OCC3COC(Cn4ccnc4)(c4ccc(Cl)cc4Cl)O3)cc2)CC1',
#   'CC(=O)N1CCN(c2ccc(OCC3COC(Cn4ccnc4)(c4ccc(Cl)cc4Cl)O3)cc2)CC1'),
#  ('Clc1ccc(CO/N=C(/Cn2ccnc2)c2ccc(Cl)cc2Cl)c(Cl)c1',
#   'Clc1ccc(CO/N=C(/Cn2ccnc2)c2ccc(Cl)cc2Cl)c(Cl)c1'),
#  ('CC(C)N1CCN(c2ccc(OCC3CO[C@](Cn4cncn4)(c4ccc(Cl)cc4Cl)O3)cc2)CC1',
#   'CC(C)N1CCN(c2ccc(OCC3CO[C@](Cn4cncn4)(c4ccc(Cl)cc4Cl)O3)cc2)CC1'),
#  ('CCC(C)n1ncn(-c2ccc(N3CCN(c4ccc(OCC5CO[C@](Cn6cncn6)(c6ccc(Cl)cc6Cl)O5)cc4)CC3)cc2)c1=O',
#   'CCC(C)n1ncn(-c2ccc(N3CCN(c4ccc(OCC5CO[C@](Cn6cncn6)(c6ccc(Cl)cc6Cl)O5)cc4)CC3)cc2)c1=O'),
#  ('Clc1ccc([C@@H](Cn2ccnc2)OCc2ccsc2Cl)c(Cl)c1',
#   'Clc1ccc([C@@H](Cn2ccnc2)OCc2ccsc2Cl)c(Cl)c1'),
#  ('Nc1cc(Cl)c(N=C2NCCN2)c(Cl)c1', 'Nc1cc(Cl)c(N=C2NCCN2)c(Cl)c1'),
#  ('CCN(CC)CCOC(=O)c1ccc(N)cc1Cl', 'CCN(CC)CCOC(=O)c1ccc(N)cc1Cl'),
#  ('CCc1nn(CCCN2CCN(c3cccc(Cl)c3)CC2)c(=O)n1CCOc1ccccc1',
#   'CCc1nn(CCCN2CCN(c3cccc(Cl)c3)CC2)c(=O)n1CCOc1ccccc1'),
#  ('O=c1n(CCCN2CCN(c3cccc(Cl)c3)CC2)nc2ccccn12',
#   'O=c1n(CCCN2CCN(c3cccc(Cl)c3)CC2)nc2ccccn12'),
#  ('NS(=O)(=O)c1cc(C(=O)O)c(NCc2ccco2)cc1Cl',
#   'NS(=O)(=O)c1cc(C(=O)O)c(NCc2ccco2)cc1Cl'),
#  ('COc1cc2ncnc(Nc3ccc(F)c(Cl)c3)c2cc1OCCCN1CCOCC1',
#   'COc1cc2ncnc(Nc3ccc(F)c(Cl)c3)c2cc1OCCCN1CCOCC1'),
#  ('CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1',
#   'CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1'),
#  ('CC(NC(C)(C)C)C(=O)c1cccc(Cl)c1', 'CC(NC(C)(C)C)C(=O)c1cccc(Cl)c1'),
#  ('CNC1CCC(c2ccc(Cl)c(Cl)c2)c2ccccc21', 'CNC1CCC(c2ccc(Cl)c(Cl)c2)c2ccccc21'),
#  ('CC(C(=O)O)c1ccc(N2CC=CC2)c(Cl)c1', 'CC(C(=O)O)c1ccc(N2CC=CC2)c(Cl)c1'),
#  ('C=CCOc1ccc(CC(=O)O)cc1Cl', 'C=CCOc1ccc(CC(=O)O)cc1Cl'),
#  ('CN1C(=O)CC(=O)N(c2ccccc2)c2cc(Cl)ccc21',
#   'CN1C(=O)CC(=O)N(c2ccccc2)c2cc(Cl)ccc21'),
#  ('CN(C)CCCN1c2ccccc2CCc2ccc(Cl)cc21', 'CN(C)CCCN1c2ccccc2CCc2ccc(Cl)cc21'),
#  ('CN(C)CCCN1c2ccccc2Sc2ccc(Cl)cc21', 'CN(C)CCCN1c2ccccc2Sc2ccc(Cl)cc21'),
#  ('NC(=O)C1CCN(CCCN2c3ccccc3Sc3ccc(Cl)cc32)CC1',
#   'NC(=O)C1CCN(CCCN2c3ccccc3Sc3ccc(Cl)cc32)CC1'),
#  ('CN1CCN(CCCN2c3ccccc3Sc3ccc(Cl)cc32)CC1',
#   'CN1CCN(CCCN2c3ccccc3Sc3ccc(Cl)cc32)CC1'),
#  ('CN1CCN(C2=Nc3cc(Cl)ccc3Nc3ccccc32)CC1',
#   'CN1CCN(C2=Nc3cc(Cl)ccc3Nc3ccccc32)CC1'),
#  ('NS(=O)(=O)c1cc2c(cc1Cl)N=CNS2(=O)=O',
#   'NS(=O)(=O)c1cc2c(cc1Cl)N=CNS2(=O)=O'),
#  ('O=C1Cc2cc(CCN3CCN(c4nsc5ccccc45)CC3)c(Cl)cc2N1',
#   'O=C1Cc2cc(CCN3CCN(c4nsc5ccccc45)CC3)c(Cl)cc2N1'),
#  ('CN1C(CCl)Nc2cc(Cl)c(S(N)(=O)=O)cc2S1(=O)=O',
#   'CN1C(CCl)Nc2cc(Cl)c(S(N)(=O)=O)cc2S1(=O)=O'),
#  ('CN1C(CSCC(F)(F)F)Nc2cc(Cl)c(S(N)(=O)=O)cc2S1(=O)=O',
#   'CN1C(CSCC(F)(F)F)Nc2cc(Cl)c(S(N)(=O)=O)cc2S1(=O)=O'),
#  ('Cc1ccccc1N1C(=O)c2cc(S(N)(=O)=O)c(Cl)cc2NC1C',
#   'Cc1ccccc1N1C(=O)c2cc(S(N)(=O)=O)c(Cl)cc2NC1C'),
#  ('O=c1[nH]c2cc(Cl)ccc2o1', 'O=c1[nH]c2cc(Cl)ccc2o1'),
#  ('NS(=O)(=O)c1cc2c(cc1Cl)NCNS2(=O)=O', 'NS(=O)(=O)c1cc2c(cc1Cl)NCNS2(=O)=O'),
#  ('CN1c2ccccc2C(NCCCCCCC(=O)O)c2ccc(Cl)cc2S1(=O)=O',
#   'CN1c2ccccc2C(NCCCCCCC(=O)O)c2ccc(Cl)cc2S1(=O)=O'),
#  ('Cc1ncc2n1-c1ccc(Cl)cc1C(c1ccccc1F)=NC2',
#   'Cc1ncc2n1-c1ccc(Cl)cc1C(c1ccccc1F)=NC2'),
#  ('Clc1ccc2c(c1)C(c1ccccc1)=NCc1nncn1-2',
#   'Clc1ccc2c(c1)C(c1ccccc1)=NCc1nncn1-2'),
#  ('CN1C(=O)C(O)N=C(c2ccccc2)c2cc(Cl)ccc21',
#   'CN1C(=O)C(O)N=C(c2ccccc2)c2cc(Cl)ccc21'),
#  ('O=C1CN=C(c2ccccc2)c2cc(Cl)ccc2N1CC(F)(F)F',
#   'O=C1CN=C(c2ccccc2)c2cc(Cl)ccc2N1CC(F)(F)F'),
#  ('Fc1ccccc1C1=NCC(=S)N(CC(F)(F)F)c2ccc(Cl)cc21',
#   'Fc1ccccc1C1=NCC(=S)N(CC(F)(F)F)c2ccc(Cl)cc21'),
#  ('CCN(CC)CCN1C(=O)CN=C(c2ccccc2F)c2cc(Cl)ccc21',
#   'CCN(CC)CCN1C(=O)CN=C(c2ccccc2F)c2cc(Cl)ccc21'),
#  ('O=C1Nc2ccc(Cl)cc2[C@@](C#CC2CC2)(C(F)(F)F)O1',
#   'O=C1Nc2ccc(Cl)cc2[C@@](C#CC2CC2)(C(F)(F)F)O1'),
#  ('CN1CCN(C2=Nc3ccccc3Oc3ccc(Cl)cc32)CC1',
#   'CN1CCN(C2=Nc3ccccc3Oc3ccc(Cl)cc32)CC1'),
#  ('Clc1ccc2c(c1)C(N1CCNCC1)=Nc1ccccc1O2',
#   'Clc1ccc2c(c1)C(N1CCNCC1)=Nc1ccccc1O2'),
#  ('Clc1ccc2c(c1)CCc1cccnc1C2=C1CCNCC1', 'Clc1ccc2c(c1)CCc1cccnc1C2=C1CCNCC1'),
#  ('CC(C)(O)c1ccccc1CCC(SCC1(CC(=O)O)CC1)c1cccc(/C=C/c2ccc3ccc(Cl)cc3n2)c1',
#   'CC(C)(O)c1ccccc1CCC(SCC1(CC(=O)O)CC1)c1cccc(/C=C/c2ccc3ccc(Cl)cc3n2)c1'),
#  ('CCN(CC)CCC[C@H](C)Nc1c2ccc(Cl)cc2nc2ccc(OC)cc12',
#   'CCN(CC)CCC[C@H](C)Nc1c2ccc(Cl)cc2nc2ccc(OC)cc12'),
#  ('CCN(CC)CCCC(C)Nc1ccnc2cc(Cl)ccc12', 'CCN(CC)CCCC(C)Nc1ccnc2cc(Cl)ccc12'),
#  ('CCN(CCO)CCCC(C)Nc1ccnc2cc(Cl)ccc12', 'CCN(CCO)CCCC(C)Nc1ccnc2cc(Cl)ccc12'),
#  ('CCN(CC)Cc1cc(Nc2ccnc3cc(Cl)ccc23)ccc1O',
#   'CCN(CC)Cc1cc(Nc2ccnc3cc(Cl)ccc23)ccc1O'),
#  ('O=C(OCC(O)CO)c1ccccc1Nc1ccnc2cc(Cl)ccc12',
#   'O=C(OCC(O)CO)c1ccccc1Nc1ccnc2cc(Cl)ccc12'),
#  ('CC(C)/N=c1\\cc2n(-c3ccc(Cl)cc3)c3ccccc3nc-2cc1Nc1ccc(Cl)cc1',
#   'CC(C)/N=c1\\cc2n(-c3ccc(Cl)cc3)c3ccccc3nc-2cc1Nc1ccc(Cl)cc1'),
#  ('CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1',
#   'CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1'),
#  ('CC(C)NC(=N)NC(=N)Nc1ccc(Cl)cc1', 'CC(C)NC(=N)NC(=N)Nc1ccc(Cl)cc1'),
#  ('N=C(NCCCCCCNC(=N)NC(=N)Nc1ccc(Cl)cc1)NC(=N)Nc1ccc(Cl)cc1',
#   'N=C(NCCCCCCNC(=N)NC(=N)Nc1ccc(Cl)cc1)NC(=N)Nc1ccc(Cl)cc1'),
#  ('CCOC(=O)C(C)(C)Oc1ccc(Cl)cc1', 'CCOC(=O)C(C)(C)Oc1ccc(Cl)cc1'),
#  ('O=C(COc1ccc(Cl)cc1)N1CCN(Cc2ccc3c(c2)OCO3)CC1',
#   'O=C(COc1ccc(Cl)cc1)N1CCN(Cc2ccc3c(c2)OCO3)CC1'),
#  ('CCCNC(=O)NS(=O)(=O)c1ccc(Cl)cc1', 'CCCNC(=O)NS(=O)(=O)c1ccc(Cl)cc1'),
#  ('O=P(O)(O)C(Sc1ccc(Cl)cc1)P(=O)(O)O', 'O=P(O)(O)C(Sc1ccc(Cl)cc1)P(=O)(O)O'),
#  ('CCc1nc(N)nc(N)c1-c1ccc(Cl)cc1', 'CCc1nc(N)nc(N)c1-c1ccc(Cl)cc1'),
#  ('CC(C(=O)O)c1ccc2oc(-c3ccc(Cl)cc3)nc2c1',
#   'CC(C(=O)O)c1ccc2oc(-c3ccc(Cl)cc3)nc2c1'),
#  ('O=C(O)Cc1csc(-c2ccc(Cl)cc2)n1', 'O=C(O)Cc1csc(-c2ccc(Cl)cc2)n1'),
#  ('CC(C)(Oc1ccc(CCNC(=O)c2ccc(Cl)cc2)cc1)C(=O)O',
#   'CC(C)(Oc1ccc(CCNC(=O)c2ccc(Cl)cc2)cc1)C(=O)O'),
#  ('COc1ccc2c(C(=O)c3ccc(Cl)cc3)c(C)n(CC(=O)O)c2c1',
#   'COc1ccc2c(C(=O)c3ccc(Cl)cc3)c(C)n(CC(=O)O)c2c1'),
#  ('CC(C)OC(=O)C(C)(C)Oc1ccc(C(=O)c2ccc(Cl)cc2)cc1',
#   'CC(C)OC(=O)C(C)(C)Oc1ccc(C(=O)c2ccc(Cl)cc2)cc1'),
#  ('Cc1cc(CC(=O)O)n(C)c1C(=O)c1ccc(Cl)cc1',
#   'Cc1cc(CC(=O)O)n(C)c1C(=O)c1ccc(Cl)cc1'),
#  ('COc1ccc2c(c1)c(CC(=O)O)c(C)n2C(=O)c1ccc(Cl)cc1',
#   'COc1ccc2c(c1)c(CC(=O)O)c(C)n2C(=O)c1ccc(Cl)cc1'),
#  ('NCC(CC(=O)O)c1ccc(Cl)cc1', 'NCC(CC(=O)O)c1ccc(Cl)cc1'),
#  ('CN(C)CCC(c1ccc(Cl)cc1)c1ccccn1', 'CN(C)CCC(c1ccc(Cl)cc1)c1ccccn1'),
#  ('O=C(O)COCCN1CCN(C(c2ccccc2)c2ccc(Cl)cc2)CC1',
#   'O=C(O)COCCN1CCN(C(c2ccccc2)c2ccc(Cl)cc2)CC1'),
#  ('OCCOCCN1CCN(C(c2ccccc2)c2ccc(Cl)cc2)CC1',
#   'OCCOCCN1CCN(C(c2ccccc2)c2ccc(Cl)cc2)CC1'),
#  ('Cc1cccc(CN2CCN(C(c3ccccc3)c3ccc(Cl)cc3)CC2)c1',
#   'Cc1cccc(CN2CCN(C(c3ccccc3)c3ccc(Cl)cc3)CC2)c1'),
#  ('CN(C)CCOC(c1ccc(Cl)cc1)c1ccccn1', 'CN(C)CCOC(c1ccc(Cl)cc1)c1ccccn1'),
#  ('CC(C)CC(N(C)C)C1(c2ccc(Cl)cc2)CCC1', 'CC(C)CC(N(C)C)C1(c2ccc(Cl)cc2)CCC1'),
#  ('CN(C)C(=O)C(CCN1CCC(O)(c2ccc(Cl)cc2)CC1)(c1ccccc1)c1ccccc1',
#   'CN(C)C(=O)C(CCN1CCC(O)(c2ccc(Cl)cc2)CC1)(c1ccccc1)c1ccccc1'),
#  ('CN1C(=O)CCS(=O)(=O)C1c1ccc(Cl)cc1', 'CN1C(=O)CCS(=O)(=O)C1c1ccc(Cl)cc1'),
#  ('CN1CCCC(n2nc(Cc3ccc(Cl)cc3)c3ccccc3c2=O)CC1',
#   'CN1CCCC(n2nc(Cc3ccc(Cl)cc3)c3ccccc3c2=O)CC1'),
#  ('CN1CCCC1CCO[C@](C)(c1ccccc1)c1ccc(Cl)cc1',
#   'CN1CCCC1CCO[C@](C)(c1ccccc1)c1ccc(Cl)cc1'),
#  ('CC1Cc2ccccc2N1NC(=O)c1ccc(Cl)c(S(N)(=O)=O)c1',
#   'CC1Cc2ccccc2N1NC(=O)c1ccc(Cl)c(S(N)(=O)=O)c1'),
#  ('NS(=O)(=O)c1cc(C2(O)NC(=O)c3ccccc32)ccc1Cl',
#   'NS(=O)(=O)c1cc(C2(O)NC(=O)c3ccccc32)ccc1Cl'),
#  ('Clc1ccc2nsnc2c1NC1=NCCN1', 'Clc1ccc2nsnc2c1NC1=NCCN1'),
#  ('Cc1nc(Nc2ncc(C(=O)Nc3c(C)cccc3Cl)s2)cc(N2CCN(CCO)CC2)n1',
#   'Cc1nc(Nc2ncc(C(=O)Nc3c(C)cccc3Cl)s2)cc(N2CCN(CCO)CC2)n1'),
#  ('Cc1onc(-c2c(Cl)cccc2Cl)c1C(=O)NC1C(=O)N2C1SC(C)(C)C2C(=O)O',
#   'Cc1onc(-c2c(Cl)cccc2Cl)c1C(=O)NC1C(=O)N2C1SC(C)(C)C2C(=O)O'),
#  ('NC(N)=NC(=O)Cc1c(Cl)cccc1Cl', 'NC(N)=NC(=O)Cc1c(Cl)cccc1Cl'),
#  ('Clc1cccc(Cl)c1NC1=NCCN1', 'Clc1cccc(Cl)c1NC1=NCCN1'),
#  ('O=C(O)Cc1ccccc1Nc1c(Cl)cccc1Cl', 'O=C(O)Cc1ccccc1Nc1c(Cl)cccc1Cl'),
#  ('Clc1ccc(CCC(Cn2ccnc2)Sc2c(Cl)cccc2Cl)cc1',
#   'Clc1ccc(CCC(Cn2ccnc2)Sc2c(Cl)cccc2Cl)cc1'),
#  ('N=C(N)N/N=C/c1c(Cl)cccc1Cl', 'N=C(N)N/N=C/c1c(Cl)cccc1Cl'),
#  ('Cc1ccc(Nc2c(F)cccc2Cl)c(CC(=O)O)c1', 'Cc1ccc(Nc2c(F)cccc2Cl)c(CC(=O)O)c1'),
#  ('Cc1onc(-c2ccccc2Cl)c1C(=O)NC1C(=O)N2C1SC(C)(C)C2C(=O)O',
#   'Cc1onc(-c2ccccc2Cl)c1C(=O)NC1C(=O)N2C1SC(C)(C)C2C(=O)O'),
#  ('Clc1ccc(C(c2ccccc2Cl)C(Cl)Cl)cc1', 'Clc1ccc(C(c2ccccc2Cl)C(Cl)Cl)cc1'),
#  ('Clc1ccccc1C(c1ccccc1)(c1ccccc1)n1ccnc1',
#   'Clc1ccccc1C(c1ccccc1)(c1ccccc1)n1ccnc1'),
#  ('CNC1(c2ccccc2Cl)CCCCC1=O', 'CNC1(c2ccccc2Cl)CCCCC1=O'),
#  ('O=C1Nc2ccc(Cl)cc2C(c2ccccc2Cl)=NC1O',
#   'O=C1Nc2ccc(Cl)cc2C(c2ccccc2Cl)=NC1O'),
#  ('CCc1cc2c(s1)N(C)C(=O)CN=C2c1ccccc1Cl',
#   'CCc1cc2c(s1)N(C)C(=O)CN=C2c1ccccc1Cl'),
#  ('O=C1CN=C(c2ccccc2Cl)c2cc([N+](=O)[O-])ccc2N1',
#   'O=C1CN=C(c2ccccc2Cl)c2cc([N+](=O)[O-])ccc2N1'),
#  ('CCOC(=O)C1=C(COCCN)NC(C)=C(C(=O)OC)C1c1ccccc1Cl',
#   'CCOC(=O)C1=C(COCCN)NC(C)=C(C(=O)OC)C1c1ccccc1Cl'),
#  ('CN1CC[C@@H](c2c(O)cc(O)c3c(=O)cc(-c4ccccc4Cl)oc23)[C@@H](O)C1',
#   'CN1CC[C@@H](c2c(O)cc(O)c3c(=O)cc(-c4ccccc4Cl)oc23)[C@@H](O)C1'),
#  ('Clc1ccccc1CN1CCc2sccc2C1', 'Clc1ccccc1CN1CCc2sccc2C1'),
#  ('COC(=O)[C@H](c1ccccc1Cl)N1CCc2sccc2C1',
#   'COC(=O)[C@H](c1ccccc1Cl)N1CCc2sccc2C1'),
#  ('Nc1nc(Cl)nc2c1ncn2C1CC(O)C(CO)O1', 'Nc1nc(Cl)nc2c1ncn2C1CC(O)C(CO)O1'),
#  ('Nc1nc(Cl)nc2c1ncn2C1OC(CO)C(O)[C@@H]1F',
#   'Nc1nc(Cl)nc2c1ncn2C1OC(CO)C(O)[C@@H]1F'),
#  ('CCCCc1nc(Cl)c(CO)n1Cc1ccc(-c2ccccc2-c2nn[nH]n2)cc1',
#   'CCCCc1nc(Cl)c(CO)n1Cc1ccc(-c2ccccc2-c2nn[nH]n2)cc1'),
#  ('CN1C(C(=O)Nc2ccccn2)=C(O)c2sc(Cl)cc2S1(=O)=O',
#   'CN1C(C(=O)Nc2ccccn2)=C(O)c2sc(Cl)cc2S1(=O)=O'),
#  ('CCCCC(=O)OCC(=O)[C@]1(O)Cc2c(O)c3c(c(O)c2C(OC2CC(NC(=O)C(F)(F)F)C(O)C(C)O2)C1)C(=O)c1c(OC)cccc1C3=O',
#   'CCCCC(=O)OCC(=O)[C@]1(O)Cc2c(O)c3c(c(O)c2C(OC2CC(NC(=O)C(F)(F)F)C(O)C(C)O2)C1)C(=O)c1c(OC)cccc1C3=O'),
#  ('FCOC(C(F)(F)F)C(F)(F)F', 'FCOC(C(F)(F)F)C(F)(F)F'),
#  ('O=c1[nH]c(=O)n(C2CC(O)C(CO)O2)cc1C(F)(F)F',
#   'O=c1[nH]c(=O)n(C2CC(O)C(CO)O2)cc1C(F)(F)F'),
#  ('O=C(NCC1CCCCN1)c1cc(OCC(F)(F)F)ccc1OCC(F)(F)F',
#   'O=C(NCC1CCCCN1)c1cc(OCC(F)(F)F)ccc1OCC(F)(F)F'),
#  ('C[C@H](Cc1cc2c(c(C(N)=O)c1)N(CCCO)CC2)NCCOc1ccccc1OCC(F)(F)F',
#   'C[C@H](Cc1cc2c(c(C(N)=O)c1)N(CCCO)CC2)NCCOc1ccccc1OCC(F)(F)F'),
#  ('CC1(C)NC(=O)N(c2ccc([N+](=O)[O-])c(C(F)(F)F)c2)C1=O',
#   'CC1(C)NC(=O)N(c2ccc([N+](=O)[O-])c(C(F)(F)F)c2)C1=O'),
#  ('CC(C)C(=O)Nc1ccc([N+](=O)[O-])c(C(F)(F)F)c1',
#   'CC(C)C(=O)Nc1ccc([N+](=O)[O-])c(C(F)(F)F)c1'),
#  ('Cc1cn(-c2cc(NC(=O)c3ccc(C)c(Nc4nccc(-c5cccnc5)n4)c3)cc(C(F)(F)F)c2)cn1',
#   'Cc1cn(-c2cc(NC(=O)c3ccc(C)c(Nc4nccc(-c5cccnc5)n4)c3)cc(C(F)(F)F)c2)cn1'),
#  ('CC(C)OC(=O)CCC/C=C\\CC1C(O)CC(O)C1/C=C/C(O)COc1cccc(C(F)(F)F)c1',
#   'CC(C)OC(=O)CCC/C=C\\CC1C(O)CC(O)C1/C=C/C(O)COc1cccc(C(F)(F)F)c1'),
#  ('CC(NCCCc1cccc(C(F)(F)F)c1)c1cccc2ccccc12',
#   'CC(NCCCc1cccc(C(F)(F)F)c1)c1cccc2ccccc12'),
#  ('CCN[C@@H](C)Cc1cccc(C(F)(F)F)c1', 'CCN[C@@H](C)Cc1cccc(C(F)(F)F)c1'),
#  ('Cc1oncc1C(=O)Nc1ccc(C(F)(F)F)cc1', 'Cc1oncc1C(=O)Nc1ccc(C(F)(F)F)cc1'),
#  ('CNCCC(Oc1ccc(C(F)(F)F)cc1)c1ccccc1', 'CNCCC(Oc1ccc(C(F)(F)F)cc1)c1ccccc1'),
#  ('COCCCC/C(=N\\OCCN)c1ccc(C(F)(F)F)cc1',
#   'COCCCC/C(=N\\OCCN)c1ccc(C(F)(F)F)cc1'),
#  ('C[C@]12C=CC(=O)NC1CCC1C2CC[C@]2(C)C(C(=O)Nc3cc(C(F)(F)F)ccc3C(F)(F)F)CCC12',
#   'C[C@]12C=CC(=O)NC1CCC1C2CC[C@]2(C)C(C(=O)Nc3cc(C(F)(F)F)ccc3C(F)(F)F)CCC12'),
#  ('FC(F)OC(F)C(F)(F)F', 'FC(F)OC(F)C(F)(F)F'),
#  ('Cc1nnc(C(C)C)n1C1CC2CCC(C1)N2CCC(NC(=O)C1CCC(F)(F)CC1)c1ccccc1',
#   'Cc1nnc(C(C)C)n1C1CC2CCC(C1)N2CCC(NC(=O)C1CCC(F)(F)CC1)c1ccccc1'),
#  ('CCCCCOC(=O)Nc1nc(=O)n(C2OC(C)C(O)C2O)cc1F',
#   'CCCCCOC(=O)Nc1nc(=O)n(C2OC(C)C(O)C2O)cc1F'),
#  ('O=c1[nH]c(=O)n(C2CC(O)C(CO)O2)cc1F', 'O=c1[nH]c(=O)n(C2CC(O)C(CO)O2)cc1F'),
#  ('C[C@H]1O[C@@H](n2cc(F)c(=O)[nH]c2=O)[C@H](O)[C@@H]1O',
#   'C[C@H]1O[C@@H](n2cc(F)c(=O)[nH]c2=O)[C@H](O)[C@@H]1O'),
#  ('Nc1nc(=O)[nH]cc1F', 'Nc1nc(=O)[nH]cc1F'),
#  ('O=c1[nH]cc(F)c(=O)[nH]1', 'O=c1[nH]cc(F)c(=O)[nH]1'),
#  ('CC1(C)OC2CC3C4CC(F)C5=CC(=O)C=C[C@]5(C)C4C(O)C[C@]3(C)[C@]2(C(=O)CO)O1',
#   'CC1(C)OC2CC3C4CC(F)C5=CC(=O)C=C[C@]5(C)C4C(O)C[C@]3(C)[C@]2(C(=O)CO)O1'),
#  ('CC(=O)OCC(=O)[C@@]12OC(C)(C)OC1CC1C3CC(F)C4=CC(=O)C=C[C@]4(C)[C@@]3(F)C(O)C[C@@]12C',
#   'CC(=O)OCC(=O)[C@@]12OC(C)(C)OC1CC1C3CC(F)C4=CC(=O)C=C[C@]4(C)[C@@]3(F)C(O)C[C@@]12C'),
#  ('CC1CC2C3CCC4=CC(=O)C=C[C@]4(C)[C@@]3(F)C(O)C[C@]2(C)[C@@]1(O)C(=O)CO',
#   'CC1CC2C3CCC4=CC(=O)C=C[C@]4(C)[C@@]3(F)C(O)C[C@]2(C)[C@@]1(O)C(=O)CO'),
#  ('C[C@]12CC(O)[C@@]3(F)C(CCC4=CC(=O)C=C[C@@]43C)C1CC(O)[C@]2(O)C(=O)CO',
#   'C[C@]12CC(O)[C@@]3(F)C(CCC4=CC(=O)C=C[C@@]43C)C1CC(O)[C@]2(O)C(=O)CO'),
#  ('CC(=O)OCC(=O)[C@@]12OC3(CCCC3)OC1CC1C3CCC4=CC(=O)C=C[C@]4(C)[C@@]3(F)C(O)C[C@@]12C',
#   'CC(=O)OCC(=O)[C@@]12OC3(CCCC3)OC1CC1C3CCC4=CC(=O)C=C[C@]4(C)[C@@]3(F)C(O)C[C@@]12C'),
#  ('C[C@]1(O)CCC2C3CCC4=CC(=O)CC[C@]4(C)[C@@]3(F)C(O)C[C@@]21C',
#   'C[C@]1(O)CCC2C3CCC4=CC(=O)CC[C@]4(C)[C@@]3(F)C(O)C[C@@]21C'),
#  ('C[C@]12CC(O)[C@@]3(F)C(CCC4=CC(=O)CC[C@@]43C)C1CC[C@]2(O)C(=O)CO',
#   'C[C@]12CC(O)[C@@]3(F)C(CCC4=CC(=O)CC[C@@]43C)C1CC[C@]2(O)C(=O)CO'),
#  ('CC(=O)OCC(=O)[C@@]1(O)CCC2C3CCC4=CC(=O)CC[C@]4(C)[C@@]3(F)C(O)C[C@@]21C',
#   'CC(=O)OCC(=O)[C@@]1(O)CCC2C3CCC4=CC(=O)CC[C@]4(C)[C@@]3(F)C(O)C[C@@]21C'),
#  ('C[C@@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C@@]3(F)[C@@H](O)C[C@]2(C)[C@H]1C(=O)CO',
#   'C[C@@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C@@]3(F)[C@@H](O)C[C@]2(C)[C@H]1C(=O)CO'),
#  ('CC(=O)[C@@]1(O)CCC2C3CC(C)C4=CC(=O)C=C[C@]4(C)[C@@]3(F)C(O)C[C@@]21C',
#   'CC(=O)[C@@]1(O)CCC2C3CC(C)C4=CC(=O)C=C[C@]4(C)[C@@]3(F)C(O)C[C@@]21C'),
#  ('C[C@H]1CN(c2c(F)c(N)c3c(=O)c(C(=O)O)cn(C4CC4)c3c2F)C[C@@H](C)N1',
#   'C[C@H]1CN(c2c(F)c(N)c3c(=O)c(C(=O)O)cn(C4CC4)c3c2F)C[C@@H](C)N1'),
#  ('Cc1c(F)c(N2CCNC(C)C2)cc2c1c(=O)c(C(=O)O)cn2C1CC1',
#   'Cc1c(F)c(N2CCNC(C)C2)cc2c1c(=O)c(C(=O)O)cn2C1CC1'),
#  ('CCn1cc(C(=O)O)c(=O)c2cc(F)c(N3CCNC(C)C3)c(F)c21',
#   'CCn1cc(C(=O)O)c(=O)c2cc(F)c(N3CCNC(C)C3)c(F)c21'),
#  ('O=C(O)c1cc(-c2ccc(F)cc2F)ccc1O', 'O=C(O)c1cc(-c2ccc(F)cc2F)ccc1O'),
#  ('OC(Cn1cncn1)(Cn1cncn1)c1ccc(F)cc1F', 'OC(Cn1cncn1)(Cn1cncn1)c1ccc(F)cc1F'),
#  ('CC1CN(c2cc3c(cc2F)c(=O)c(C(=O)O)cn3-c2ccc(F)cc2F)CCN1',
#   'CC1CN(c2cc3c(cc2F)c(=O)c(C(=O)O)cn3-c2ccc(F)cc2F)CCN1'),
#  ('NC1C2CN(c3nc4c(cc3F)c(=O)c(C(=O)O)cn4-c3ccc(F)cc3F)CC12',
#   'NC1C2CN(c3nc4c(cc3F)c(=O)c(C(=O)O)cn4-c3ccc(F)cc3F)CC12'),
#  ('CC(N)C(=O)NC(C)C(=O)NC1C2CN(c3nc4c(cc3F)c(=O)c(C(=O)O)cn4-c3ccc(F)cc3F)CC21',
#   'CC(N)C(=O)NC(C)C(=O)NC1C2CN(c3nc4c(cc3F)c(=O)c(C(=O)O)cn4-c3ccc(F)cc3F)CC21'),
#  ('CCC(C(C)O)n1ncn(-c2ccc(N3CCN(c4ccc(OCC5CO[C@@](Cn6cncn6)(c6ccc(F)cc6F)C5)cc4)CC3)cc2)c1=O',
#   'CCC(C(C)O)n1ncn(-c2ccc(N3CCN(c4ccc(OCC5CO[C@@](Cn6cncn6)(c6ccc(F)cc6F)C5)cc4)CC3)cc2)c1=O'),
#  ('C[C@@H](c1ncncc1F)[C@](O)(Cn1cncn1)c1ccc(F)cc1F',
#   'C[C@@H](c1ncncc1F)[C@](O)(Cn1cncn1)c1ccc(F)cc1F'),
#  ('CC(=O)NCC1CN(c2ccc(N3CCOCC3)c(F)c2)C(=O)O1',
#   'CC(=O)NCC1CN(c2ccc(N3CCOCC3)c(F)c2)C(=O)O1'),
#  ('CC(C(=O)O)c1ccc(-c2ccccc2)c(F)c1', 'CC(C(=O)O)c1ccc(-c2ccccc2)c(F)c1'),
#  ('OC(CNCC(O)C1CCc2cc(F)ccc2O1)C1CCc2cc(F)ccc2O1',
#   'OC(CNCC(O)C1CCc2cc(F)ccc2O1)C1CCc2cc(F)ccc2O1'),
#  ('CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(F)ccc1-2',
#   'CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(F)ccc1-2'),
#  ('COc1c(N2CC3CCCNC3C2)c(F)cc2c(=O)c(C(=O)O)cn(C3CC3)c12',
#   'COc1c(N2CC3CCCNC3C2)c(F)cc2c(=O)c(C(=O)O)cn(C3CC3)c12'),
#  ('O=C(O)c1cn(C2CC2)c2cc(N3CCNCC3)c(F)cc2c1=O',
#   'O=C(O)c1cn(C2CC2)c2cc(N3CCNCC3)c(F)cc2c1=O'),
#  ('CCn1cc(C(=O)O)c(=O)c2cc(F)c(N3CCNCC3)cc21',
#   'CCn1cc(C(=O)O)c(=O)c2cc(F)c(N3CCNCC3)cc21'),
#  ('COCC(=O)O[C@]1(CCN(C)CCCc2nc3ccccc3[nH]2)CCc2cc(F)ccc2C1C(C)C',
#   'COCC(=O)O[C@]1(CCN(C)CCCc2nc3ccccc3[nH]2)CCc2cc(F)ccc2C1C(C)C'),
#  ('CO/N=C1\\CN(c2nc3c(cc2F)c(=O)c(C(=O)O)cn3C2CC2)CC1CN',
#   'CO/N=C1\\CN(c2nc3c(cc2F)c(=O)c(C(=O)O)cn3C2CC2)CC1CN'),
#  ('CC1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)cn1c23',
#   'CC1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)cn1c23'),
#  ('Cc1nc2n(c(=O)c1CCN1CCC(c3noc4cc(F)ccc34)CC1)CCCC2',
#   'Cc1nc2n(c(=O)c1CCN1CCC(c3noc4cc(F)ccc34)CC1)CCCC2'),
#  ('CCN(CC)CCNC(=O)c1c(C)[nH]c(/C=C2\\C(=O)Nc3ccc(F)cc32)c1C',
#   'CCN(CC)CCNC(=O)c1c(C)[nH]c(/C=C2\\C(=O)Nc3ccc(F)cc32)c1C'),
#  ('COCc1c(C(C)C)nc(C(C)C)c(/C=C/C(O)CC(O)CC(=O)O)c1-c1ccc(F)cc1',
#   'COCc1c(C(C)C)nc(C(C)C)c(/C=C/C(O)CC(O)CC(=O)O)c1-c1ccc(F)cc1'),
#  ('CC(C)n1c(/C=C/C(O)CC(O)CC(=O)O)c(-c2ccc(F)cc2)c2ccccc21',
#   'CC(C)n1c(/C=C/C(O)CC(O)CC(=O)O)c(-c2ccc(F)cc2)c2ccccc21'),
#  ('O=C(O)C[C@H](O)C[C@H](O)/C=C/c1c(C2CC2)nc2ccccc2c1-c1ccc(F)cc1',
#   'O=C(O)C[C@H](O)C[C@H](O)/C=C/c1c(C2CC2)nc2ccccc2c1-c1ccc(F)cc1'),
#  ('CC(C)c1c(C(=O)Nc2ccccc2)c(-c2ccccc2)c(-c2ccc(F)cc2)n1CCC(O)CC(O)CC(=O)O',
#   'CC(C)c1c(C(=O)Nc2ccccc2)c(-c2ccccc2)c(-c2ccc(F)cc2)n1CCC(O)CC(O)CC(=O)O'),
#  ('O=C(CCCN1CC=C(n2c(=O)[nH]c3ccccc32)CC1)c1ccc(F)cc1',
#   'O=C(CCCN1CC=C(n2c(=O)[nH]c3ccccc32)CC1)c1ccc(F)cc1'),
#  ('O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc(F)cc2)CC1',
#   'O=c1[nH]c2ccccc2n1C1CCN(CCCC(c2ccc(F)cc2)c2ccc(F)cc2)CC1'),
#  ('O=C1NCN(c2ccccc2)C12CCN(CCCC(c1ccc(F)cc1)c1ccc(F)cc1)CC2',
#   'O=C1NCN(c2ccccc2)C12CCN(CCCC(c1ccc(F)cc1)c1ccc(F)cc1)CC2'),
#  ('O=C1C(CCC(O)c2ccc(F)cc2)C(c2ccc(O)cc2)N1c1ccc(F)cc1',
#   'O=C1C(CCC(O)c2ccc(F)cc2)C(c2ccc(O)cc2)N1c1ccc(F)cc1'),
#  ('CC1CN(C2CCC(C#N)(c3ccc(F)cc3)CC2)CC[C@]1(C(=O)O)c1ccccc1',
#   'CC1CN(C2CCC(C#N)(c3ccc(F)cc3)CC2)CC[C@]1(C(=O)O)c1ccccc1'),
#  ('CN(C)CCCC1(c2ccc(F)cc2)OCc2cc(C#N)ccc21',
#   'CN(C)CCCC1(c2ccc(F)cc2)OCc2cc(C#N)ccc21'),
#  ('Fc1ccc(C2CCNCC2COc2ccc3c(c2)OCO3)cc1',
#   'Fc1ccc(C2CCNCC2COc2ccc3c(c2)OCO3)cc1'),
#  ('COc1ccc(CCN2CCC(Nc3nc4ccccc4n3Cc3ccc(F)cc3)CC2)cc1',
#   'COc1ccc(CCN2CCC(Nc3nc4ccccc4n3Cc3ccc(F)cc3)CC2)cc1'),
#  ('O=c1[nH]c(=O)n(C2OC(CO)C(O)C2F)cc1I',
#   'O=c1[nH]c(=O)n(C2OC(CO)C(O)C2F)cc1I'),
#  ('COCC(=O)Nc1c(I)c(C(=O)NCC(O)CO)c(I)c(C(=O)N(C)CC(O)CO)c1I',
#   'COCC(=O)Nc1c(I)c(C(=O)NCC(O)CO)c(I)c(C(=O)N(C)CC(O)CO)c1I'),
#  ('CC(O)C(=O)Nc1c(I)c(C(=O)NC(CO)CO)c(I)c(C(=O)NC(CO)CO)c1I',
#   'CC(O)C(=O)Nc1c(I)c(C(=O)NC(CO)CO)c(I)c(C(=O)NC(CO)CO)c1I'),
#  ('CNC(=O)c1c(I)c(C(=O)NCC(=O)Nc2c(I)c(C(=O)O)c(I)c(C(=O)NCCO)c2I)c(I)c(N(C)C(C)=O)c1I',
#   'CNC(=O)c1c(I)c(C(=O)NCC(=O)Nc2c(I)c(C(=O)O)c(I)c(C(=O)NCCO)c2I)c(I)c(N(C)C(C)=O)c1I'),
#  ('CC(=O)N(CC(O)CN(C(C)=O)c1c(I)c(C(=O)NCC(O)CO)c(I)c(C(=O)NCC(O)CO)c1I)c1c(I)c(C(=O)NCC(O)CO)c(I)c(C(=O)NCC(O)CO)c1I',
#   'CC(=O)N(CC(O)CN(C(C)=O)c1c(I)c(C(=O)NCC(O)CO)c(I)c(C(=O)NCC(O)CO)c1I)c1c(I)c(C(=O)NCC(O)CO)c(I)c(C(=O)NCC(O)CO)c1I'),
#  ('CC(=O)N(CC(O)CO)c1c(I)c(C(=O)NCC(O)CO)c(I)c(C(=O)NCC(O)CO)c1I',
#   'CC(=O)N(CC(O)CO)c1c(I)c(C(=O)NCC(O)CO)c(I)c(C(=O)NCC(O)CO)c1I'),
#  ('O=C(NCC(O)CO)c1c(I)c(C(=O)NCC(O)CO)c(I)c(N(CCO)C(=O)CO)c1I',
#   'O=C(NCC(O)CO)c1c(I)c(C(=O)NCC(O)CO)c(I)c(N(CCO)C(=O)CO)c1I'),
#  ('CC(=O)Nc1c(I)c(NC(C)=O)c(I)c(C(=O)O)c1I',
#   'CC(=O)Nc1c(I)c(NC(C)=O)c(I)c(C(=O)O)c1I'),
#  ('CC(=O)Nc1c(I)cc(I)c(C(=O)O)c1I', 'CC(=O)Nc1c(I)cc(I)c(C(=O)O)c1I'),
#  ('O=C(CCCCC(=O)Nc1c(I)cc(I)c(C(=O)O)c1I)Nc1c(I)cc(I)c(C(=O)O)c1I',
#   'O=C(CCCCC(=O)Nc1c(I)cc(I)c(C(=O)O)c1I)Nc1c(I)cc(I)c(C(=O)O)c1I'),
#  ('CCc1oc2ccccc2c1C(=O)c1cc(I)c(O)c(I)c1',
#   'CCc1oc2ccccc2c1C(=O)c1cc(I)c(O)c(I)c1'),
#  ('CCCCc1oc2ccccc2c1C(=O)c1cc(I)c(OCCN(CC)CC)c(I)c1',
#   'CCCCc1oc2ccccc2c1C(=O)c1cc(I)c(OCCN(CC)CC)c(I)c1'),
#  ('N[C@@H](Cc1cc(I)c(Oc2cc(I)c(O)c(I)c2)c(I)c1)C(=O)O',
#   'N[C@@H](Cc1cc(I)c(Oc2cc(I)c(O)c(I)c2)c(I)c1)C(=O)O'),
#  ('NC(Cc1cc(I)c(Oc2ccc(O)c(I)c2)c(I)c1)C(=O)O',
#   'NC(Cc1cc(I)c(Oc2ccc(O)c(I)c2)c(I)c1)C(=O)O'),
#  ('C#CCNC1CCc2ccccc21', 'C#CCNC1CCc2ccccc21'),
#  ('CC(CN(C)C)CN1c2ccccc2CCc2ccccc21', 'CC(CN(C)C)CN1c2ccccc2CCc2ccccc21'),
#  ('CNCCCC12CCC(c3ccccc31)c1ccccc12', 'CNCCCC12CCC(c3ccccc31)c1ccccc12'),
#  ('CNCCCC1c2ccccc2C=Cc2ccccc21', 'CNCCCC1c2ccccc2C=Cc2ccccc21'),
#  ('CN(C)CCCN1c2ccccc2CCc2ccccc21', 'CN(C)CCCN1c2ccccc2CCc2ccccc21'),
#  ('CNCCCN1c2ccccc2CCc2ccccc21', 'CNCCCN1c2ccccc2CCc2ccccc21'),
#  ('N=C(N)NCCN1CCCCCCC1', 'N=C(N)NCCN1CCCCCCC1'),
#  ('CN(C)CCC=C1c2ccccc2C=Cc2ccccc21', 'CN(C)CCC=C1c2ccccc2C=Cc2ccccc21'),
#  ('CN(C)CCC=C1c2ccccc2CCc2ccccc21', 'CN(C)CCC=C1c2ccccc2CCc2ccccc21'),
#  ('CNCCC=C1c2ccccc2CCc2ccccc21', 'CNCCC=C1c2ccccc2CCc2ccccc21'),
#  ('CN(C/C=C/C#CC(C)(C)C)Cc1cccc2ccccc12',
#   'CN(C/C=C/C#CC(C)(C)C)Cc1cccc2ccccc12'),
#  ('CN(C/C=C/c1ccccc1)Cc1cccc2ccccc12', 'CN(C/C=C/c1ccccc1)Cc1cccc2ccccc12'),
#  ('CN(Cc1ccc(C(C)(C)C)cc1)Cc1cccc2ccccc12',
#   'CN(Cc1ccc(C(C)(C)C)cc1)Cc1cccc2ccccc12'),
#  ('C#CCN(C)Cc1ccccc1', 'C#CCN(C)Cc1ccccc1'),
#  ('CN[C@@H](C)Cc1ccccc1', 'CN[C@@H](C)Cc1ccccc1'),
#  ('CN1CCC(=C2c3ccccc3C=Cc3ccccc32)CC1', 'CN1CCC(=C2c3ccccc3C=Cc3ccccc32)CC1'),
#  ('CN1CCN(C(c2ccccc2)c2ccccc2)CC1', 'CN1CCN(C(c2ccccc2)c2ccccc2)CC1'),
#  ('CN1CCN2c3ccccc3Cc3ccccc3C2C1', 'CN1CCN2c3ccccc3Cc3ccccc3C2C1'),
#  ('C1N2CN3CN1CN(C2)C3', 'C1N2CN3CN1CN(C2)C3'),
#  ('C1CCC(C(CC2CCCCN2)C2CCCCC2)CC1', 'C1CCC(C(CC2CCCCN2)C2CCCCC2)CC1'),
#  ('c1ccc2c(c1)CCCC2C1=NCCN1', 'c1ccc2c(c1)CCCC2C1=NCCN1'),
#  ('c1ccc2c(CC3=NCCN3)cccc2c1', 'c1ccc2c(CC3=NCCN3)cccc2c1'),
#  ('c1ccc(CC2=NCCN2)cc1', 'c1ccc(CC2=NCCN2)cc1'),
#  ('CC(N)C12CC3CC(CC(C3)C1)C2', 'CC(N)C12CC3CC(CC(C3)C1)C2'),
#  ('CC(C)(N)Cc1ccccc1', 'CC(C)(N)Cc1ccccc1'),
#  ('CC(N)Cc1ccccc1', 'CC(N)Cc1ccccc1'),
#  ('CC12CC3CC(C)(C1)CC(N)(C3)C2', 'CC12CC3CC(C)(C1)CC(N)(C3)C2'),
#  ('NC12CC3CC(CC(C3)C1)C2', 'NC12CC3CC(CC(C3)C1)C2'),
#  ('CN1Cc2c(N)cccc2C(c2ccccc2)C1', 'CN1Cc2c(N)cccc2C(c2ccccc2)C1'),
#  ('CNCC(O)c1ccc(OC(=O)C(C)(C)C)c(OC(=O)C(C)(C)C)c1',
#   'CNCC(O)c1ccc(OC(=O)C(C)(C)C)c(OC(=O)C(C)(C)C)c1'),
#  ('COC(=O)C(c1ccccc1)C1CCCCN1', 'COC(=O)C(c1ccccc1)C1CCCCN1'),
#  ('CCC(C)C(=O)OC1CC(O)C=C2C=CC(C)C(CCC(O)CC(O)CC(=O)O)C21',
#   'CCC(C)C(=O)OC1CC(O)C=C2C=CC(C)C(CCC(O)CC(O)CC(=O)O)C21'),
#  ('CN1C2CCC1CC(OC(=O)C(CO)c1ccccc1)C2', 'CN1C2CCC1CC(OC(=O)C(CO)c1ccccc1)C2'),
#  ('CCOC(=O)C(CCc1ccccc1)NC(C)C(=O)N1C(C(=O)O)CC2CCCC21',
#   'CCOC(=O)C(CCc1ccccc1)NC(C)C(=O)N1C(C(=O)O)CC2CCCC21'),
#  ('CCCC(NC(C)C(=O)N1C(C(=O)O)CC2CCCCC21)C(=O)OCC',
#   'CCCC(NC(C)C(=O)N1C(C(=O)O)CC2CCCCC21)C(=O)OCC'),
#  ('CCOC(=O)C(CCc1ccccc1)NC(C)C(=O)N1C(C(=O)O)CC2CCCCC21',
#   'CCOC(=O)C(CCc1ccccc1)NC(C)C(=O)N1C(C(=O)O)CC2CCCCC21'),
#  ('CCOC(=O)C(CCc1ccccc1)NC(C)C(=O)N1CCCC1C(=O)O',
#   'CCOC(=O)C(CCc1ccccc1)NC(C)C(=O)N1CCCC1C(=O)O'),
#  ('CCOC(=O)C(CCc1ccccc1)NC(C)C(=O)N1Cc2ccccc2CC1C(=O)O',
#   'CCOC(=O)C(CCc1ccccc1)NC(C)C(=O)N1Cc2ccccc2CC1C(=O)O'),
#  ('CCN(CC)CC#CCOC(=O)C(O)(c1ccccc1)C1CCCCC1',
#   'CCN(CC)CC#CCOC(=O)C(O)(c1ccccc1)C1CCCCC1'),
#  ('C#C[C@]1(OC(C)=O)CCC2C3CCC4=CC(OC(C)=O)CCC4C3CC[C@@]21C',
#   'C#C[C@]1(OC(C)=O)CCC2C3CCC4=CC(OC(C)=O)CCC4C3CC[C@@]21C'),
#  ('CC(=O)OCC(CCn1cnc2cnc(N)nc21)COC(C)=O',
#   'CC(=O)OCC(CCn1cnc2cnc(N)nc21)COC(C)=O'),
#  ('CC(=O)Oc1c(C)cc(OCC(O)CNC(C)C)c(C)c1C',
#   'CC(=O)Oc1c(C)cc(OCC(O)CNC(C)C)c(C)c1C'),
#  ('CC(=O)Oc1cc(C(C)C)c(OCCN(C)C)cc1C', 'CC(=O)Oc1cc(C(C)C)c(OCCN(C)C)cc1C'),
#  ('CC(=O)Oc1ccc(C(c2ccc(OC(C)=O)cc2)c2ccccn2)cc1',
#   'CC(=O)Oc1ccc(C(c2ccc(OC(C)=O)cc2)c2ccccn2)cc1'),
#  ('CC(=O)Oc1ccccc1C(=O)O', 'CC(=O)Oc1ccccc1C(=O)O'),
#  ('CCN(CC)CCOC(=O)C1(C2CCCCC2)CCCCC1', 'CCN(CC)CCOC(=O)C1(C2CCCCC2)CCCCC1'),
#  ('CCOC(=O)C1(c2ccccc2)CCN(C)CC1', 'CCOC(=O)C1(c2ccccc2)CCN(C)CC1'),
#  ('CCOC(=O)C1(c2ccccc2)CCN(CCC(C#N)(c2ccccc2)c2ccccc2)CC1',
#   'CCOC(=O)C1(c2ccccc2)CCN(CCC(C#N)(c2ccccc2)c2ccccc2)CC1'),
#  ('CCOC(=O)C1(c2ccccc2)CCN(CCc2ccc(N)cc2)CC1',
#   'CCOC(=O)C1(c2ccccc2)CCN(CCc2ccc(N)cc2)CC1'),
#  ('COC(=O)C1=C(C)NC(C)=C(C(=O)OC)C1c1ccccc1[N+](=O)[O-]',
#   'COC(=O)C1=C(C)NC(C)=C(C(=O)OC)C1c1ccccc1[N+](=O)[O-]'),
#  ('COC(=O)C1=C(C)NC(C)=C(C(=O)OCC(C)C)C1c1ccccc1[N+](=O)[O-]',
#   'COC(=O)C1=C(C)NC(C)=C(C(=O)OCC(C)C)C1c1ccccc1[N+](=O)[O-]'),
#  ('COCCOC(=O)C1=C(C)NC(C)=C(C(=O)OC(C)C)C1c1cccc([N+](=O)[O-])c1',
#   'COCCOC(=O)C1=C(C)NC(C)=C(C(=O)OC(C)C)C1c1cccc([N+](=O)[O-])c1'),
#  ('CCOC(=O)C1=C(C)NC(C)=C(C(=O)OC)[C@H]1c1cccc([N+](=O)[O-])c1',
#   'CCOC(=O)C1=C(C)NC(C)=C(C(=O)OC)[C@H]1c1cccc([N+](=O)[O-])c1'),
#  ('CCC(=O)OC1CCC2C3CCC4=CC(=O)CC[C@]4(C)C3CC[C@]12C',
#   'CCC(=O)OC1CCC2C3CCC4=CC(=O)CC[C@]4(C)C3CC[C@]12C'),
#  ('COC(=O)CCC(=O)CN', 'COC(=O)CCC(=O)CN'),
#  ('CCCCC(=O)OC1CCC2C3CCc4cc(O)ccc4C3CC[C@]12C',
#   'CCCCC(=O)OC1CCC2C3CCc4cc(O)ccc4C3CC[C@]12C'),
#  ('CCCCCCC(=O)OC1CCC2C3CCC4=CC(=O)CCC4(C)C3CCC12C',
#   'CCCCCCC(=O)OC1CCC2C3CCC4=CC(=O)CCC4(C)C3CCC12C'),
#  ('CCOC(=O)CNC(C(=O)N1CCC1C(=O)NCc1ccc(/C(N)=N/O)cc1)C1CCCCC1',
#   'CCOC(=O)CNC(C(=O)N1CCC1C(=O)NCc1ccc(/C(N)=N/O)cc1)C1CCCCC1'),
#  ('CCN(C)C(=O)Oc1cccc(C(C)N(C)C)c1', 'CCN(C)C(=O)Oc1cccc(C(C)N(C)C)c1'),
#  ('O=C(OC1CN2CCC1CC2)N1CCc2ccccc2C1c1ccccc1',
#   'O=C(OC1CN2CCC1CC2)N1CCc2ccccc2C1c1ccccc1'),
#  ('COC(=O)NC(C(=O)NC(Cc1ccccc1)C(O)CN(Cc1ccc(-c2ccccn2)cc1)NC(=O)C(NC(=O)OC)C(C)(C)C)C(C)(C)C',
#   'COC(=O)NC(C(=O)NC(Cc1ccccc1)C(O)CN(Cc1ccc(-c2ccccn2)cc1)NC(=O)C(NC(=O)OC)C(C)(C)C)C(C)(C)C'),
#  ('CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2C',
#   'CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)C1N2C'),
#  ('COC(=O)Nc1nc2ccc(C(=O)c3ccccc3)cc2[nH]1',
#   'COC(=O)Nc1nc2ccc(C(=O)c3ccccc3)cc2[nH]1'),
#  ('O=C(OC1CC2CC3CC(C1)N2CC3=O)c1c[nH]c2ccccc12',
#   'O=C(OC1CC2CC3CC(C1)N2CC3=O)c1c[nH]c2ccccc12'),
#  ('CCN(CC)CCOC(=O)c1ccc(N)cc1', 'CCN(CC)CCOC(=O)c1ccc(N)cc1'),
#  ('CCCCNc1ccc(C(=O)OCCN(C)C)cc1', 'CCCCNc1ccc(C(=O)OCCN(C)C)cc1'),
#  ('CCCCNc1ccc(C(=O)OCCOCCOCCOCCOCCOCCOCCOCCOCCOC)cc1',
#   'CCCCNc1ccc(C(=O)OCCOCCOCCOCCOCCOCCOCCOCCOCCOC)cc1'),
#  ('Cc1ccc(C(=O)Oc2ccc(C(O)CNC(C)(C)C)cc2OC(=O)c2ccc(C)cc2)cc1',
#   'Cc1ccc(C(=O)Oc2ccc(C(O)CNC(C)(C)C)cc2OC(=O)c2ccc(C)cc2)cc1'),
#  ('COC(=O)C1C(OC(=O)c2ccccc2)CC2CCC1N2C',
#   'COC(=O)C1C(OC(=O)c2ccccc2)CC2CCC1N2C'),
#  ('O=C(Oc1ccccc1C(=O)O)c1ccccc1O', 'O=C(Oc1ccccc1C(=O)O)c1ccccc1O'),
#  ('COC(c1ccccc1)(c1ccccc1)C(Oc1nc(C)cc(C)n1)C(=O)O',
#   'COC(c1ccccc1)(c1ccccc1)C(Oc1nc(C)cc(C)n1)C(=O)O'),
#  ('CN(C)CCOC(C)(c1ccccc1)c1ccccn1', 'CN(C)CCOC(C)(c1ccccc1)c1ccccn1'),
#  ('CCOC(=O)C1=CC(OC(CC)CC)C(NC(C)=O)C(N)C1',
#   'CCOC(=O)C1=CC(OC(CC)CC)C(NC(C)=O)C(N)C1'),
#  ('CNCCC(Oc1ccccc1C)c1ccccc1', 'CNCCC(Oc1ccccc1C)c1ccccc1'),
#  ('CC(C[N+](C)(C)C)OC(=N)[O-]', 'CC(C[N+](C)(C)C)OC(=N)[O-]'),
#  ('CCOC(=O)OC1(C(=O)COC(=O)CC)CCC2C3CCC4=CC(=O)C=CC4(C)C3C(O)CC21C',
#   'CCOC(=O)OC1(C(=O)COC(=O)CC)CCC2C3CCC4=CC(=O)C=CC4(C)C3C(O)CC21C'),
#  ('CN1C2CCC1CC(OC(c1ccccc1)c1ccccc1)C2',
#   'CN1C2CCC1CC(OC(c1ccccc1)c1ccccc1)C2'),
#  ('CN(C)CCOC(c1ccccc1)c1ccccc1', 'CN(C)CCOC(c1ccccc1)c1ccccc1'),
#  ('Cc1ccccc1C(OCCN(C)C)c1ccccc1', 'Cc1ccccc1C(OCCN(C)C)c1ccccc1'),
#  ('COc1cc2c(c(OC)c1OC)-c1ccc(OC)c(=O)cc1C(NC(C)=O)CC2',
#   'COc1cc2c(c(OC)c1OC)-c1ccc(OC)c(=O)cc1C(NC(C)=O)CC2'),
#  ('COC(=O)C1C2CC3c4[nH]c5cc(OC)ccc5c4CCN3CC2CC(OC(=O)c2cc(OC)c(OC)c(OC)c2)C1OC',
#   'COC(=O)C1C2CC3c4[nH]c5cc(OC)ccc5c4CCN3CC2CC(OC(=O)c2cc(OC)c(OC)c(OC)c2)C1OC'),
#  ('COc1ccc(CN2CCNCC2)c(OC)c1OC', 'COc1ccc(CN2CCNCC2)c(OC)c1OC'),
#  ('COc1cc(NCc2ccc3nc(N)nc(N)c3c2C)cc(OC)c1OC',
#   'COc1cc(NCc2ccc3nc(N)nc(N)c3c2C)cc(OC)c1OC'),
#  ('COc1cc(C(=O)NCc2ccc(OCCN(C)C)cc2)cc(OC)c1OC',
#   'COc1cc(C(=O)NCc2ccc(OCCN(C)C)cc2)cc(OC)c1OC'),
#  ('COc1cc(Cc2cnc(N)nc2N)cc(OC)c1OC', 'COc1cc(Cc2cnc(N)nc2N)cc(OC)c1OC'),
#  ('COc1cc(C)c(/C=C/C(C)=C/C=C/C(C)=C/C(=O)O)c(C)c1C',
#   'COc1cc(C)c(/C=C/C(C)=C/C=C/C(C)=C/C(=O)O)c(C)c1C'),
#  ('CCOC(=O)/C=C(C)/C=C/C=C(C)/C=C/c1c(C)cc(OC)c(C)c1C',
#   'CCOC(=O)/C=C(C)/C=C/C=C(C)/C=C/c1c(C)cc(OC)c(C)c1C'),
#  ('COc1cc(NC(C)CCCN)c2ncccc2c1', 'COc1cc(NC(C)CCCN)c2ncccc2c1'),
#  ('COc1cccc([C@@]2(O)CCCCC2CN(C)C)c1', 'COc1cccc([C@@]2(O)CCCCC2CN(C)C)c1'),
#  ('COc1cc(CNC(=O)CCCC/C=C/C(C)C)ccc1O', 'COc1cc(CNC(=O)CCCC/C=C/C(C)C)ccc1O'),
#  ('COc1cc(/C=C/C(=O)CC(=O)/C=C/c2ccc(O)c(OC)c2)ccc1O',
#   'COc1cc(/C=C/C(=O)CC(=O)/C=C/c2ccc(O)c(OC)c2)ccc1O'),
#  ('COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C)cc1OC',
#   'COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C)cc1OC'),
#  ('CCOC(=O)C(CCc1ccccc1)NC(C)C(=O)N1Cc2cc(OC)c(OC)cc2CC1C(=O)O',
#   'CCOC(=O)C(CCc1ccccc1)NC(C)C(=O)N1Cc2cc(OC)c(OC)cc2CC1C(=O)O'),
#  ('C#C[C@]1(O)CCC2C3CCc4cc(OC)ccc4C3CC[C@@]21C',
#   'C#C[C@]1(O)CCC2C3CCc4cc(OC)ccc4C3CC[C@@]21C'),
#  ('CCC1=CC2CN(C1)Cc1c([nH]c3ccccc13)[C@@](C(=O)OC)(c1cc3c(cc1OC)N(C)C1[C@@](O)(C(=O)OC)C(OC(C)=O)[C@]4(CC)C=CCN5CC[C@]31C54)C2',
#   'CCC1=CC2CN(C1)Cc1c([nH]c3ccccc13)[C@@](C(=O)OC)(c1cc3c(cc1OC)N(C)C1[C@@](O)(C(=O)OC)C(OC(C)=O)[C@]4(CC)C=CCN5CC[C@]31C54)C2'),
#  ('CC[C@]1(O)CC2CN(CCc3c([nH]c4ccccc34)[C@@](C(=O)OC)(c3cc4c(cc3OC)N(C)C3[C@@](O)(C(=O)OC)C(OC(C)=O)[C@]5(CC)C=CCN6CC[C@]43C65)C2)C1',
#   'CC[C@]1(O)CC2CN(CCc3c([nH]c4ccccc34)[C@@](C(=O)OC)(c3cc4c(cc3OC)N(C)C3[C@@](O)(C(=O)OC)C(OC(C)=O)[C@]5(CC)C=CCN6CC[C@]43C65)C2)C1'),
#  ('CC[C@]1(O)CC2CN(CCc3c([nH]c4ccccc34)[C@@](C(=O)OC)(c3cc4c(cc3OC)N(C=O)C3[C@@](O)(C(=O)OC)C(OC(C)=O)[C@]5(CC)C=CCN6CC[C@]43C65)C2)C1',
#   'CC[C@]1(O)CC2CN(CCc3c([nH]c4ccccc34)[C@@](C(=O)OC)(c3cc4c(cc3OC)N(C=O)C3[C@@](O)(C(=O)OC)C(OC(C)=O)[C@]5(CC)C=CCN6CC[C@]43C65)C2)C1'),
#  ('COc1ccc2c(c1)[C@]13CCCC[C@H]1[C@@H](C2)N(C)CC3',
#   'COc1ccc2c(c1)[C@]13CCCC[C@H]1[C@@H](C2)N(C)CC3'),
#  ('COc1ccc2[nH]cc(CCNC(C)=O)c2c1', 'COc1ccc2[nH]cc(CCNC(C)=O)c2c1'),
#  ('COc1ccc2cc(C(C)C(=O)O)ccc2c1', 'COc1ccc2cc(C(C)C(=O)O)ccc2c1'),
#  ('COc1ccc2cc(CCC(C)=O)ccc2c1', 'COc1ccc2cc(CCC(C)=O)ccc2c1'),
#  ('C=CC1CN2CCC1CC2C(O)c1ccnc2ccc(OC)cc12',
#   'C=CC1CN2CCC1CC2C(O)c1ccnc2ccc(OC)cc12'),
#  ('COc1ccc(OC)c(C(O)C(C)N)c1', 'COc1ccc(OC)c(C(O)C(C)N)c1'),
#  ('COc1ccc(OC)c(C(O)CNC(=O)CN)c1', 'COc1ccc(OC)c(C(O)CNC(=O)CN)c1'),
#  ('COc1ccc(C(=O)Nc2ccccc2CCC2CCCCN2C)cc1',
#   'COc1ccc(C(=O)Nc2ccccc2CCC2CCCCN2C)cc1'),
#  ('COc1ccc(C(CN(C)C)C2(O)CCCCC2)cc1', 'COc1ccc(C(CN(C)C)C2(O)CCCCC2)cc1'),
#  ('CCCCC(CC)COC(=O)/C=C/c1ccc(OC)cc1', 'CCCCC(CC)COC(=O)/C=C/c1ccc(OC)cc1'),
#  ('COc1ccc(-c2ccc3cc(C(=O)O)ccc3c2)cc1C12CC3CC(CC(C3)C1)C2',
#   'COc1ccc(-c2ccc3cc(C(=O)O)ccc3c2)cc1C12CC3CC(CC(C3)C1)C2'),
#  ('Cc1cccc(C)c1OCC(=O)N[C@@H](Cc1ccccc1)[C@@H](O)C[C@H](Cc1ccccc1)NC(=O)[C@H](C(C)C)N1CCCNC1=O',
#   'Cc1cccc(C)c1OCC(=O)N[C@@H](Cc1ccccc1)[C@@H](O)C[C@H](Cc1ccccc1)NC(=O)[C@H](C(C)C)N1CCCNC1=O'),
#  ('CC(C)COCC(CN(Cc1ccccc1)c1ccccc1)N1CCCC1',
#   'CC(C)COCC(CN(Cc1ccccc1)c1ccccc1)N1CCCC1'),
#  ('NC(=O)OCC(COC(N)=O)c1ccccc1', 'NC(=O)OCC(COC(N)=O)c1ccccc1'),
#  ('Cc1cccc(C)c1OCC(C)N', 'Cc1cccc(C)c1OCC(C)N'),
#  ('CC(COc1ccccc1)NC(C)C(O)c1ccc(O)cc1', 'CC(COc1ccccc1)NC(C)C(O)c1ccc(O)cc1'),
#  ('CCCCCC(O)CCC1C(O)CC2Cc3c(cccc3OCC(=O)O)CC21',
#   'CCCCCC(O)CCC1C(O)CC2Cc3c(cccc3OCC(=O)O)CC21'),
#  ('O=C(O)COc1nn(Cc2ccccc2)c2ccccc12', 'O=C(O)COc1nn(Cc2ccccc2)c2ccccc12'),
#  ('CC(C)(C)NCC(O)COc1cccc2c1CC(O)C(O)C2',
#   'CC(C)(C)NCC(O)COc1cccc2c1CC(O)C(O)C2'),
#  ('CC(C)(C)NCC(O)COc1cccc2c1CCC(=O)N2', 'CC(C)(C)NCC(O)COc1cccc2c1CCC(=O)N2'),
#  ('CC(C)(C)NCC(O)COc1cccc2c1CCCC2=O', 'CC(C)(C)NCC(O)COc1cccc2c1CCCC2=O'),
#  ('CC(C)(C)NCC(O)COc1ccccc1C1CCCC1', 'CC(C)(C)NCC(O)COc1ccccc1C1CCCC1'),
#  ('CC(C)NCC(O)COc1cccc2[nH]ccc12', 'CC(C)NCC(O)COc1cccc2[nH]ccc12'),
#  ('CC(C)NCC(O)COc1cccc2ccccc12', 'CC(C)NCC(O)COc1cccc2ccccc12'),
#  ('CCCC(=O)Nc1ccc(OCC(O)CNC(C)C)c(C(C)=O)c1',
#   'CCCC(=O)Nc1ccc(OCC(O)CNC(C)C)c(C(C)=O)c1'),
#  ('CC(C)NCC(O)COc1ccc(CC(N)=O)cc1', 'CC(C)NCC(O)COc1ccc(CC(N)=O)cc1'),
#  ('COC(=O)CCc1ccc(OCC(O)CNC(C)C)cc1', 'COC(=O)CCc1ccc(OCC(O)CNC(C)C)cc1'),
#  ('COCCc1ccc(OCC(O)CNC(C)C)cc1', 'COCCc1ccc(OCC(O)CNC(C)C)cc1'),
#  ('CC(C)NCC(O)COc1ccc(CCOCC2CC2)cc1', 'CC(C)NCC(O)COc1ccc(CCOCC2CC2)cc1'),
#  ('CC(C)NCC(O)COc1ccc(COCCOC(C)C)cc1', 'CC(C)NCC(O)COc1ccc(COCCOC(C)C)cc1'),
#  ('CCCNCC(O)COc1ccccc1C(=O)CCc1ccccc1', 'CCCNCC(O)COc1ccccc1C(=O)CCc1ccccc1'),
#  ('COc1ccccc1OCC(O)COC(N)=O', 'COc1ccccc1OCC(O)COC(N)=O'),
#  ('CCOc1cc(CC(=O)NC(CC(C)C)c2ccccc2N2CCCCC2)ccc1C(=O)O',
#   'CCOc1cc(CC(=O)NC(CC(C)C)c2ccccc2N2CCCCC2)ccc1C(=O)O'),
#  ('CCOc1ccc(NC(C)=O)cc1', 'CCOc1ccc(NC(C)=O)cc1'),
#  ('CCOc1nc2cccc(C(=O)O)c2n1Cc1ccc(-c2ccccc2-c2nn[nH]n2)cc1',
#   'CCOc1nc2cccc(C(=O)O)c2n1Cc1ccc(-c2ccccc2-c2nn[nH]n2)cc1'),
#  ('C=CCOC=O', 'C=CCOC=O'),
#  ('CCCOc1ccc(C(=O)OCCN(CC)CC)cc1N', 'CCCOc1ccc(C(=O)OCCN(CC)CC)cc1N'),
#  ('Cc1ccc(C)c(OCCCC(C)(C)C(=O)O)c1', 'Cc1ccc(C)c(OCCCC(C)(C)C(=O)O)c1'),
#  ('CCCCCOc1ccc(-c2ccc(-c3ccc(C(=O)NC4CC(O)C(O)NC(=O)[C@@H]5C(O)C(C)CN5C(=O)[C@H](C(C)O)NC(=O)[C@H](C(O)C(O)c5ccc(O)cc5)NC(=O)[C@@H]5CC(O)CN5C(=O)[C@H](C(C)O)NC4=O)cc3)cc2)cc1',
#   'CCCCCOc1ccc(-c2ccc(-c3ccc(C(=O)NC4CC(O)C(O)NC(=O)[C@@H]5C(O)C(C)CN5C(=O)[C@H](C(C)O)NC(=O)[C@H](C(O)C(O)c5ccc(O)cc5)NC(=O)[C@@H]5CC(O)CN5C(=O)[C@H](C(C)O)NC4=O)cc3)cc2)cc1'),
#  ('N=C(N)c1ccc(OCCCCCOc2ccc(C(=N)N)cc2)cc1',
#   'N=C(N)c1ccc(OCCCCCOc2ccc(C(=N)N)cc2)cc1'),
#  ('COCCCOc1cc(CC(CC(N)C(O)CC(C(=O)NCC(C)(C)C(N)=O)C(C)C)C(C)C)ccc1OC',
#   'COCCCOc1cc(CC(CC(N)C(O)CC(C(=O)NCC(C)(C)C(N)=O)C(C)C)C(C)C)ccc1OC'),
#  ('CC/C(=C(\\c1ccccc1)c1ccc(OCCN(C)C)cc1)c1ccccc1',
#   'CC/C(=C(\\c1ccccc1)c1ccc(OCCN(C)C)cc1)c1ccccc1'),
#  ('CN(C)CCOc1ccccc1Cc1ccccc1', 'CN(C)CCOc1ccccc1Cc1ccccc1'),
#  ('CCN(CC)CCOc1cccc(OCCN(CC)CC)c1OCCN(CC)CC',
#   'CCN(CC)CCOc1cccc(OCCN(CC)CC)c1OCCN(CC)CC'),
#  ('C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1',
#   'C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1'),
#  ('C[N+](C)(C)CCOC(=N)[O-]', 'C[N+](C)(C)CCOC(=N)[O-]'),
#  ('CCC[C@@](C)(COC(N)=O)COC(=O)NC(C)C', 'CCC[C@@](C)(COC(N)=O)COC(=O)NC(C)C'),
#  ('O=C(OOC(=O)c1ccccc1)c1ccccc1', 'O=C(OOC(=O)c1ccccc1)c1ccccc1'),
#  ('CCC(=O)O[C@](Cc1ccccc1)(c1ccccc1)C(C)CN(C)C',
#   'CCC(=O)O[C@](Cc1ccccc1)(c1ccccc1)C(C)CN(C)C'),
#  ('O=[N+]([O-])OCC(CO[N+](=O)[O-])O[N+](=O)[O-]',
#   'O=[N+]([O-])OCC(CO[N+](=O)[O-])O[N+](=O)[O-]'),
#  ('CC(C(=O)O)c1cccc(Oc2ccccc2)c1', 'CC(C(=O)O)c1cccc(Oc2ccccc2)c1'),
#  ('C=CCC1/C=C(\\C)CC(C)CC(OC)C2O[C@@](O)(C(=O)C(=O)N3CCCCC3C(=O)OC(/C(C)=C/C3CCC(O)C(OC)C3)C(C)C(O)CC1=O)C(C)CC2OC',
#   'C=CCC1/C=C(\\C)CC(C)CC(OC)C2O[C@@](O)(C(=O)C(=O)N3CCCCC3C(=O)OC(/C(C)=C/C3CCC(O)C(OC)C3)C(C)C(O)CC1=O)C(C)CC2OC'),
#  ('CCC1OC(=O)C(C)C(=O)C(C)C(OC2OC(C)CC(N(C)C)C2O)[C@@](C)(OC)CC(C)C(=O)C(C)C2N(CCCCn3cnc(-c4cccnc4)c3)C(=O)O[C@]12C',
#   'CCC1OC(=O)C(C)C(=O)C(C)C(OC2OC(C)CC(N(C)C)C2O)[C@@](C)(OC)CC(C)C(=O)C(C)C2N(CCCCn3cnc(-c4cccnc4)c3)C(=O)O[C@]12C'),
#  ('CCC1OC(=O)C(C)C(OC2C[C@@](C)(OC)C(O)C(C)O2)C(C)C(OC2OC(C)CC(N(C)C)C2O)[C@](C)(O)CC(C)CN(C)C(C)C(O)[C@]1(C)O',
#   'CCC1OC(=O)C(C)C(OC2C[C@@](C)(OC)C(O)C(C)O2)C(C)C(OC2OC(C)CC(N(C)C)C2O)[C@](C)(O)CC(C)CN(C)C(C)C(O)[C@]1(C)O'),
#  ('CCC1OC(=O)C(C)C(OC2C[C@@](C)(OC)C(O)C(C)O2)C(C)C(OC2OC(C)CC(N(C)C)C2O)[C@](C)(OC)CC(C)C(=O)C(C)C(O)[C@]1(C)O',
#   'CCC1OC(=O)C(C)C(OC2C[C@@](C)(OC)C(O)C(C)O2)C(C)C(OC2OC(C)CC(N(C)C)C2O)[C@](C)(OC)CC(C)C(=O)C(C)C(O)[C@]1(C)O'),
#  ('CC(=O)NC1C(N=C(N)N)C=C(C(=O)O)OC1C(O)C(O)CO',
#   'CC(=O)NC1C(N=C(N)N)C=C(C(=O)O)OC1C(O)C(O)CO'),
#  ('O=C1C(O)=C(O)OC1C(O)CO', 'O=C1C(O)=C(O)OC1C(O)CO'),
#  ('CN1C(=O)OC(C)(C)C1=O', 'CN1C(=O)OC(C)(C)C1=O'),
#  ('COC1C(OC(N)=O)C(O)C(Oc2ccc3c(=O)c(NC(=O)c4ccc(O)c(CC=C(C)C)c4)c(O)oc3c2C)OC1(C)C',
#   'COC1C(OC(N)=O)C(O)C(Oc2ccc3c(=O)c(NC(=O)c4ccc(O)c(CC=C(C)C)c4)c(O)oc3c2C)OC1(C)C'),
#  ('COC1CC(OC2C(C)C(=O)OC(C)C(C)C(OC(C)=O)C(C)C(=O)[C@]3(CO3)CC(C)C(OC3OC(C)CC(N(C)C)C3OC(C)=O)C2C)OC(C)C1OC(C)=O',
#   'COC1CC(OC2C(C)C(=O)OC(C)C(C)C(OC(C)=O)C(C)C(=O)[C@]3(CO3)CC(C)C(OC3OC(C)CC(N(C)C)C3OC(C)=O)C2C)OC(C)C1OC(C)=O'),
#  ('Cc1c2oc3c(C)ccc(C(=O)NC4C(=O)NC(C(C)C)C(=O)N5CCCC5C(=O)N(C)CC(=O)N(C)C(C(C)C)C(=O)OC4C)c3nc-2c(C(=O)NC2C(=O)NC(C(C)C)C(=O)N3CCCC3C(=O)N(C)CC(=O)N(C)C(C(C)C)C(=O)OC2C)c(N)c1=O',
#   'Cc1c2oc3c(C)ccc(C(=O)NC4C(=O)NC(C(C)C)C(=O)N5CCCC5C(=O)N(C)CC(=O)N(C)C(C(C)C)C(=O)OC4C)c3nc-2c(C(=O)NC2C(=O)NC(C(C)C)C(=O)N3CCCC3C(=O)N(C)CC(=O)N(C)C(C(C)C)C(=O)OC2C)c(N)c1=O'),
#  ('CC1OC(OC2C(CO)OC(OC3C(CO)OC(O)C(O)C3O)C(O)C2O)C(O)C(O)C1NC1C=C(CO)C(O)C(O)C1O',
#   'CC1OC(OC2C(CO)OC(OC3C(CO)OC(O)C(O)C3O)C(O)C2O)C(O)C(O)C1NC1C=C(CO)C(O)C(O)C1O'),
#  ('CC(=O)[C@]1(O)Cc2c(O)c3c(c(O)c2C(OC2CC(N)C(O)C(C)O2)C1)C(=O)c1ccccc1C3=O',
#   'CC(=O)[C@]1(O)Cc2c(O)c3c(c(O)c2C(OC2CC(N)C(O)C(C)O2)C1)C(=O)c1ccccc1C3=O'),
#  ('COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)(C(=O)CO)CC3OC1CC(N)C(O)C(C)O1',
#   'COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)(C(=O)CO)CC3OC1CC(N)C(O)C(C)O1'),
#  ('CC1OC(OC2C(O)CC(OC3C(O)CC(OC4CC[C@@]5(C)C(CCC6C5CC(O)[C@]5(C)C(C7=CC(=O)OC7)CC[C@]65O)C4)OC3C)OC2C)CC(O)C1O',
#   'CC1OC(OC2C(O)CC(OC3C(O)CC(OC4CC[C@@]5(C)C(CCC6C5CC(O)[C@]5(C)C(C7=CC(=O)OC7)CC[C@]65O)C4)OC3C)OC2C)CC(O)C1O'),
#  ('Cc1cn(C2C=CC(CO)O2)c(=O)[nH]c1=O', 'Cc1cn(C2C=CC(CO)O2)c(=O)[nH]c1=O'),
#  ('COC1CC2CCC(C)[C@@](O)(O2)C(=O)C(=O)N2CCCCC2C(=O)OC(C(C)CC2CCC(O)C(OC)C2)CC(=O)C(C)/C=C(\\C)C(O)C(OC)C(=O)C(C)CC(C)/C=C/C=C/C=C/1C',
#   'COC1CC2CCC(C)[C@@](O)(O2)C(=O)C(=O)N2CCCCC2C(=O)OC(C(C)CC2CCC(O)C(OC)C2)CC(=O)C(C)/C=C(\\C)C(O)C(OC)C(=O)C(C)CC(C)/C=C/C=C/C=C/1C'),
#  ('CCC(C)(C)C(=O)OC1CC(C)C=C2C=CC(C)C(CCC3CC(O)CC(=O)O3)C21',
#   'CCC(C)(C)C(=O)OC1CC(C)C=C2C=CC(C)C(CCC3CC(O)CC(=O)O3)C21'),
#  ('CCC(C)C(=O)OC1CC(C)C=C2C=CC(C)C(CCC3CC(O)CC(=O)O3)C21',
#   'CCC(C)C(=O)OC1CC(C)C=C2C=CC(C)C(CCC3CC(O)CC(=O)O3)C21'),
#  ('CCCCCCCCCCCC(CC1OC(=O)C1CCCCCC)OC(=O)C(CC(C)C)NC=O',
#   'CCCCCCCCCCCC(CC1OC(=O)C1CCCCCC)OC(=O)C(CC(C)C)NC=O'),
#  ('C/C(=C\\C(=O)OCCCCCCCCC(=O)O)CC1OCC(CC2OC2C(C)C(C)O)C(O)C1O',
#   'C/C(=C\\C(=O)OCCCCCCCCC(=O)O)CC1OCC(CC2OC2C(C)C(C)O)C(O)C1O'),
#  ('Nc1ccn(C2CCC(CO)O2)c(=O)n1', 'Nc1ccn(C2CCC(CO)O2)c(=O)n1'),
#  ('O=c1[nH]cnc2c1ncn2C1CCC(CO)O1', 'O=c1[nH]cnc2c1ncn2C1CCC(CO)O1'),
#  ('NCC1OC(OC2C(CO)OC(OC3C(O)C(N)CC(N)C3OC3OC(CN)C(O)C(O)C3N)C2O)C(N)C(O)C1O',
#   'NCC1OC(OC2C(CO)OC(OC3C(O)C(N)CC(N)C3OC3OC(CN)C(O)C(O)C3N)C2O)C(N)C(O)C1O'),
#  ('NCC1OC(OC2C(CO)OC(OC3C(O)C(N)CC(N)C3OC3OC(CO)C(O)C(O)C3N)C2O)C(N)C(O)C1O',
#   'NCC1OC(OC2C(CO)OC(OC3C(O)C(N)CC(N)C3OC3OC(CO)C(O)C(O)C3N)C2O)C(N)C(O)C1O'),
#  ('NCC1OC(OC2C(N)CC(N)C(OC3OC(CO)C(O)C(N)C3O)C2O)C(O)C(O)C1O',
#   'NCC1OC(OC2C(N)CC(N)C(OC3OC(CO)C(O)C(N)C3O)C2O)C(O)C(O)C1O'),
#  ('Cc1cn(C2CC(N=[N+]=[N-])C(CO)O2)c(=O)[nH]c1=O',
#   'Cc1cn(C2CC(N=[N+]=[N-])C(CO)O2)c(=O)[nH]c1=O'),
#  ('NCC1OC(OC2C(N)CC(N)C(OC3OC(CO)C(O)C(N)C3O)C2O)C(N)CC1O',
#   'NCC1OC(OC2C(N)CC(N)C(OC3OC(CO)C(O)C(N)C3O)C2O)C(N)CC1O'),
#  ('NC1C(O)OC(CO)C(O)C1O', 'NC1C(O)OC(CO)C(O)C1O'),
#  ('CN(N=O)C(=O)NC1C(O)OC(CO)C(O)C1O', 'CN(N=O)C(=O)NC1C(O)OC(CO)C(O)C1O'),
#  ('CNC1C(OC2C(OC3C(O)C(O)C(NC(=N)N)C(O)C3NC(=N)N)OC(C)[C@]2(O)C=O)OC(CO)C(O)C1O',
#   'CNC1C(OC2C(OC3C(O)C(O)C(NC(=N)N)C(O)C3NC(=N)N)OC(C)[C@]2(O)C=O)OC(CO)C(O)C1O'),
#  ('OCC1OC(OC2C(CO)OC(O)C(O)C2O)C(O)C(O)C1O',
#   'OCC1OC(OC2C(CO)OC(O)C(O)C2O)C(O)C(O)C1O'),
#  ('Nc1ccn(C2OC(CO)C(O)C2O)c(=O)n1', 'Nc1ccn(C2OC(CO)C(O)C2O)c(=O)n1'),
#  ('Nc1ncn(C2OC(CO)C(O)C2O)c(=O)n1', 'Nc1ncn(C2OC(CO)C(O)C2O)c(=O)n1'),
#  ('NC(=O)c1ncn(C2OC(CO)C(O)C2O)n1', 'NC(=O)c1ncn(C2OC(CO)C(O)C2O)n1'),
#  ('Cc1cn(C2CC(O)C(CO)O2)c(=O)[nH]c1=O', 'Cc1cn(C2CC(O)C(CO)O2)c(=O)[nH]c1=O'),
#  ('OCC1OC(n2cnc3c2N=CNCC3O)CC1O', 'OCC1OC(n2cnc3c2N=CNCC3O)CC1O'),
#  ('CCOc1nc2cccc(C(=O)OCc3oc(=O)oc3C)c2n1Cc1ccc(-c2ccccc2-c2noc(=O)[nH]2)cc1',
#   'CCOc1nc2cccc(C(=O)OCc3oc(=O)oc3C)c2n1Cc1ccc(-c2ccccc2-c2noc(=O)[nH]2)cc1'),
#  ('CNC(C)C1CCC(N)C(OC2C(N)CC(N)C(OC3OCC(C)(O)C(NC)C3O)C2O)O1',
#   'CNC(C)C1CCC(N)C(OC2C(N)CC(N)C(OC3OCC(C)(O)C(NC)C3O)C2O)O1'),
#  ('NC1=NC(=O)C(c2ccccc2)O1', 'NC1=NC(=O)C(c2ccccc2)O1'),
#  ('O=C1OC2(c3ccc(O)cc3Oc3cc(O)ccc32)c2ccccc21',
#   'O=C1OC2(c3ccc(O)cc3Oc3cc(O)ccc32)c2ccccc21'),
#  ('COc1cc(C2c3cc4c(cc3C(OC3OC5COC(C)OC5C(O)C3O)C3COC(=O)C23)OCO4)cc(OC)c1O',
#   'COc1cc(C2c3cc4c(cc3C(OC3OC5COC(C)OC5C(O)C3O)C3COC(=O)C23)OCO4)cc(OC)c1O'),
#  ('OC1COC2C(O)COC12', 'OC1COC2C(O)COC12'),
#  ('O=[N+]([O-])OC1COC2C(O)COC12', 'O=[N+]([O-])OC1COC2C(O)COC12'),
#  ('O=[N+]([O-])OC1COC2C(O[N+](=O)[O-])COC12',
#   'O=[N+]([O-])OC1COC2C(O[N+](=O)[O-])COC12'),
#  ('CN1C2CC(OC(=O)C(CO)c3ccccc3)CC1C1OC12',
#   'CN1C2CC(OC(=O)C(CO)c3ccccc3)CC1C1OC12'),
#  ('CC(=O)OC1C(=O)[C@]2(C)C(O)CC3OC[C@@]3(OC(C)=O)C2C(OC(=O)c2ccccc2)[C@]2(O)CC(OC(=O)C(O)C(NC(=O)c3ccccc3)c3ccccc3)C(C)=C1C2(C)C',
#   'CC(=O)OC1C(=O)[C@]2(C)C(O)CC3OC[C@@]3(OC(C)=O)C2C(OC(=O)c2ccccc2)[C@]2(O)CC(OC(=O)C(O)C(NC(=O)c3ccccc3)c3ccccc3)C(C)=C1C2(C)C'),
#  ('CC(=O)O[C@@]12COC1CC(O)[C@@]1(C)C(=O)C(O)C3=C(C)C(OC(=O)C(O)C(NC(=O)OC(C)(C)C)c4ccccc4)C[C@@](O)(C(OC(=O)c4ccccc4)C21)C3(C)C',
#   'CC(=O)O[C@@]12COC1CC(O)[C@@]1(C)C(=O)C(O)C3=C(C)C(OC(=O)C(O)C(NC(=O)OC(C)(C)C)c4ccccc4)C[C@@](O)(C(OC(=O)c4ccccc4)C21)C3(C)C'),
#  ('CC1CCC2C(C)C(=O)OC3O[C@@]4(C)CCC1[C@]32OO4',
#   'CC1CCC2C(C)C(=O)OC3O[C@@]4(C)CCC1[C@]32OO4'),
#  ('CN1CC[C@]23c4c5ccc(O)c4OC2C(=O)CCC3C1C5',
#   'CN1CC[C@]23c4c5ccc(O)c4OC2C(=O)CCC3C1C5'),
#  ('C=C1CC[C@@]2(O)C3Cc4ccc(O)c5c4[C@@]2(CCN3CC2CC2)C1O5',
#   'C=C1CC[C@@]2(O)C3Cc4ccc(O)c5c4[C@@]2(CCN3CC2CC2)C1O5'),
#  ('O=C1CC[C@@]2(O)C3Cc4ccc(O)c5c4[C@@]2(CCN3CC2CC2)C1O5',
#   'O=C1CC[C@@]2(O)C3Cc4ccc(O)c5c4[C@@]2(CCN3CC2CC2)C1O5'),
#  ('C=CCN1CC[C@]23c4c5ccc(O)c4OC2C(=O)CC[C@@]3(O)C1C5',
#   'C=CCN1CC[C@]23c4c5ccc(O)c4OC2C(=O)CC[C@@]3(O)C1C5'),
#  ('Oc1ccc2c3c1OC1C(O)CC[C@@]4(O)C(C2)N(CC2CCC2)CC[C@]314',
#   'Oc1ccc2c3c1OC1C(O)CC[C@@]4(O)C(C2)N(CC2CCC2)CC[C@]314'),
#  ('COc1ccc2c3c1OC1C(=O)CC[C@@]4(O)C(C2)N(C)CC[C@]314',
#   'COc1ccc2c3c1OC1C(=O)CC[C@@]4(O)C(C2)N(C)CC[C@]314'),
#  ('C[C@H]1O[C@@H](O[C@H]2[C@@H](O)C[C@H](O[C@H]3[C@@H](O)C[C@H](O[C@H]4CC[C@]5(C)[C@H]6CC[C@]7(C)[C@@H](C8=CC(=O)OC8)CC[C@]7(O)[C@@H]6CC[C@@H]5C4)O[C@@H]3C)O[C@@H]2C)C[C@H](O)[C@@H]1O',
#   'C[C@H]1O[C@@H](O[C@H]2[C@@H](O)C[C@H](O[C@H]3[C@@H](O)C[C@H](O[C@H]4CC[C@]5(C)[C@H]6CC[C@]7(C)[C@@H](C8=CC(=O)OC8)CC[C@]7(O)[C@@H]6CC[C@@H]5C4)O[C@@H]3C)O[C@@H]2C)C[C@H](O)[C@@H]1O'),
#  ('CCC1C(=O)OCC1Cc1cncn1C', 'CCC1C(=O)OCC1Cc1cncn1C'),
#  ('CN(C)CCc1c[nH]c2ccc(CC3COC(=O)N3)cc12',
#   'CN(C)CCc1c[nH]c2ccc(CC3COC(=O)N3)cc12'),
#  ('CC[C@@]1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3nc2-1',
#   'CC[C@@]1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3nc2-1'),
#  ('COc1cc(C2c3cc4c(cc3C(O)C3COC(=O)C23)OCO4)cc(OC)c1OC',
#   'COc1cc(C2c3cc4c(cc3C(O)C3COC(=O)C23)OCO4)cc(OC)c1OC'),
#  ('COc1cc2nc(N3CCN(C(=O)C4CCCO4)CC3)nc(N)c2cc1OC',
#   'COc1cc2nc(N3CCN(C(=O)C4CCCO4)CC3)nc(N)c2cc1OC'),
#  ('COc1cc2nc(N(C)CCCNC(=O)C3CCCO3)nc(N)c2cc1OC',
#   'COc1cc2nc(N(C)CCCNC(=O)C3CCCO3)nc(N)c2cc1OC'),
#  ('C[C@H]1[C@@H](c2ccccc2)OCCN1C', 'C[C@H]1[C@@H](c2ccccc2)OCCN1C'),
#  ('CCc1c(C)[nH]c2c1C(=O)C(CN1CCOCC1)CC2',
#   'CCc1c(C)[nH]c2c1C(=O)C(CN1CCOCC1)CC2'),
#  ('CCN1CC(CCN2CCOCC2)C(c2ccccc2)(c2ccccc2)C1=O',
#   'CCN1CC(CCN2CCOCC2)C(c2ccccc2)(c2ccccc2)C1=O'),
#  ('O=C1OCCN1/N=C/c1ccc([N+](=O)[O-])o1',
#   'O=C1OCCN1/N=C/c1ccc([N+](=O)[O-])o1'),
#  ('CCc1cccc2c3c([nH]c12)C(CC)(CC(=O)O)OCC3',
#   'CCc1cccc2c3c([nH]c12)C(CC)(CC(=O)O)OCC3'),
#  ('CCC(=O)NCC[C@@H]1CCc2ccc3c(c21)CCO3',
#   'CCC(=O)NCC[C@@H]1CCc2ccc3c(c21)CCO3'),
#  ('NC(=O)C(c1ccccc1)(c1ccccc1)C1CCN(CCc2ccc3c(c2)CCO3)C1',
#   'NC(=O)C(c1ccccc1)(c1ccccc1)C1CCN(CCc2ccc3c(c2)CCO3)C1'),
#  ('C[C@]12COC(=O)CC1CCC1C2CC[C@@]2(C)C1CC[C@]2(C)O',
#   'C[C@]12COC(=O)CC1CCC1C2CC[C@@]2(C)C1CC[C@]2(C)O'),
#  ('COc1c(C)c2c(c(O)c1C/C=C(\\C)CCC(=O)O)C(=O)OC2',
#   'COc1c(C)c2c(c(O)c1C/C=C(\\C)CCC(=O)O)C(=O)OC2'),
#  ('COc1c(C)c2c(c(O)c1C/C=C(\\C)CCC(=O)OCCN1CCOCC1)C(=O)OC2',
# ...
#  ('CN/C(=C\\[N+](=O)[O-])NCCSCc1ccc(CN(C)C)o1',
#   'CN/C(=C\\[N+](=O)[O-])NCCSCc1ccc(CN(C)C)o1'),
#  ('CC(=O)NCCCS(=O)(=O)O', 'CC(=O)NCCCS(=O)(=O)O'),
#  ('CC(CCC(=O)NCCS(=O)(=O)O)C1CCC2C3C(O)CC4CC(O)CCC4(C)C3CCC12C',
#   'CC(CCC(=O)NCCS(=O)(=O)O)C1CCC2C3C(O)CC4CC(O)CCC4(C)C3CCC12C'),
#  ('O=S(=O)(O)CCS', 'O=S(=O)(O)CCS'),
#  ('Cc1c(N(C)CS(=O)(=O)O)c(=O)n(-c2ccccc2)n1C',
#   'Cc1c(N(C)CS(=O)(=O)O)c(=O)n(-c2ccccc2)n1C'),
#  ('CO[C@H]1O[C@H](COS(=O)(=O)O)[C@@H](O[C@@H]2O[C@@H](C(=O)O)[C@@H](O[C@H]3O[C@H](COS(=O)(=O)O)[C@@H](O[C@@H]4O[C@H](C(=O)O)[C@@H](O[C@H]5O[C@H](COS(=O)(=O)O)[C@@H](O)[C@H](O)[C@H]5NS(=O)(=O)O)[C@H](O)[C@H]4O)[C@H](OS(=O)(=O)O)[C@H]3NS(=O)(=O)O)[C@H](O)[C@H]2OS(=O)(=O)O)[C@H](O)[C@H]1NS(=O)(=O)O',
#   'CO[C@H]1O[C@H](COS(=O)(=O)O)[C@@H](O[C@@H]2O[C@@H](C(=O)O)[C@@H](O[C@H]3O[C@H](COS(=O)(=O)O)[C@@H](O[C@@H]4O[C@H](C(=O)O)[C@@H](O[C@H]5O[C@H](COS(=O)(=O)O)[C@@H](O)[C@H](O)[C@H]5NS(=O)(=O)O)[C@H](O)[C@H]4O)[C@H](OS(=O)(=O)O)[C@H]3NS(=O)(=O)O)[C@H](O)[C@H]2OS(=O)(=O)O)[C@H](O)[C@H]1NS(=O)(=O)O'),
#  ('C=C1C2CCC3C4(C)CC(OC5OC(CO)C(OS(=O)(=O)O)C(OS(=O)(=O)O)C5OC(=O)CC(C)C)CC(C(=O)O)C4CCC3(C2)C1O',
#   'C=C1C2CCC3C4(C)CC(OC5OC(CO)C(OS(=O)(=O)O)C(OS(=O)(=O)O)C5OC(=O)CC(C)C)CC(C(=O)O)C4CCC3(C2)C1O'),
#  ('CS(=O)(=O)OCCCCOS(C)(=O)=O', 'CS(=O)(=O)OCCCCOS(C)(=O)=O'),
#  ('CCCCCOc1ccc(-c2cc(-c3ccc(C(=O)NC4CC(O)C(O)NC(=O)C5C(O)C(C)CN5C(=O)C(C(O)CC(N)=O)NC(=O)C(C(O)C(O)c5ccc(O)c(OS(=O)(=O)O)c5)NC(=O)C5CC(O)CN5C(=O)C(C(C)O)NC4=O)cc3)no2)cc1',
#   'CCCCCOc1ccc(-c2cc(-c3ccc(C(=O)NC4CC(O)C(O)NC(=O)C5C(O)C(C)CN5C(=O)C(C(O)CC(N)=O)NC(=O)C(C(O)C(O)c5ccc(O)c(OS(=O)(=O)O)c5)NC(=O)C5CC(O)CN5C(=O)C(C(C)O)NC4=O)cc3)no2)cc1'),
#  ('CCOC(=O)CC(SP(=S)(OC)OC)C(=O)OCC', 'CCOC(=O)CC(SP(=S)(OC)OC)C(=O)OCC'),
#  ('NCCCNCCSP(=O)(O)O', 'NCCCNCCSP(=O)(O)O'),
#  ('CCN(CC)C(=S)SSC(=S)N(CC)CC', 'CCN(CC)C(=S)SSC(=S)N(CC)CC'),
#  ('Cn1cnc([N+](=O)[O-])c1Sc1ncnc2nc[nH]c12',
#   'Cn1cnc([N+](=O)[O-])c1Sc1ncnc2nc[nH]c12'),
#  ('CN1C(C(=O)Nc2ccccn2)=C(O)c2ccccc2S1(=O)=O',
#   'CN1C(C(=O)Nc2ccccn2)=C(O)c2ccccc2S1(=O)=O'),
#  ('Cc1cc(NC(=O)C2=C(O)c3ccccc3S(=O)(=O)N2C)no1',
#   'Cc1cc(NC(=O)C2=C(O)c3ccccc3S(=O)(=O)N2C)no1'),
#  ('CCC(C)C(N)C1=NCC(C(=O)NC(CC(C)C)C(=O)NC(CCC(=O)O)C(=O)NC(C(=O)NC2CCCCNC(=O)C(CC(N)=O)NC(=O)C(CC(=O)O)NC(=O)C(Cc3cnc[nH]3)NC(=O)C(Cc3ccccc3)NC(=O)C(C(C)CC)NC(=O)C(CCCN)NC2=O)C(C)CC)S1',
#   'CCC(C)C(N)C1=NCC(C(=O)NC(CC(C)C)C(=O)NC(CCC(=O)O)C(=O)NC(C(=O)NC2CCCCNC(=O)C(CC(N)=O)NC(=O)C(CC(=O)O)NC(=O)C(Cc3cnc[nH]3)NC(=O)C(Cc3ccccc3)NC(=O)C(C(C)CC)NC(=O)C(CCCN)NC2=O)C(C)CC)S1'),
#  ('CC1(COc2ccc(CC3SC(=O)NC3=O)cc2)CCCCC1',
#   'CC1(COc2ccc(CC3SC(=O)NC3=O)cc2)CCCCC1'),
#  ('Cc1c(C)c2c(c(C)c1O)CCC(C)(COc1ccc(CC3SC(=O)NC3=O)cc1)O2',
#   'Cc1c(C)c2c(c(C)c1O)CCC(C)(COc1ccc(CC3SC(=O)NC3=O)cc1)O2'),
#  ('CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1',
#   'CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1'),
#  ('CCc1ccc(CCOc2ccc(CC3SC(=O)NC3=O)cc2)nc1',
#   'CCc1ccc(CCOc2ccc(CC3SC(=O)NC3=O)cc2)nc1'),
#  ('CC1=C(C(=O)O)N2C(=O)C(NC(=O)C(N)C3=CCC=CC3)C2SC1',
#   'CC1=C(C(=O)O)N2C(=O)C(NC(=O)C(N)C3=CCC=CC3)C2SC1'),
#  ('CC1=C(C(=O)O)N2C(=O)C(NC(=O)C(N)c3ccc(O)cc3)C2SC1',
#   'CC1=C(C(=O)O)N2C(=O)C(NC(=O)C(N)c3ccc(O)cc3)C2SC1'),
#  ('CC(=O)OCC1=C(C(=O)O)N2C(=O)C(NC(=O)CSc3ccncc3)C2SC1',
#   'CC(=O)OCC1=C(C(=O)O)N2C(=O)C(NC(=O)CSc3ccncc3)C2SC1'),
#  ('CC1(C)SC2C(NC(=O)C(C(=O)O)c3ccccc3)C(=O)N2C1C(=O)O',
#   'CC1(C)SC2C(NC(=O)C(C(=O)O)c3ccccc3)C(=O)N2C1C(=O)O'),
#  ('CC1(C)SC2C(NC(=O)C(N)c3ccc(O)cc3)C(=O)N2C1C(=O)O',
#   'CC1(C)SC2C(NC(=O)C(N)c3ccc(O)cc3)C(=O)N2C1C(=O)O'),
#  ('CC1(C)SC2C(NC(=O)C(N)c3ccccc3)C(=O)N2C1C(=O)O',
#   'CC1(C)SC2C(NC(=O)C(N)c3ccccc3)C(=O)N2C1C(=O)O'),
#  ('CCN1CCN(C(=O)NC(C(=O)NC2C(=O)N3C2SC(C)(C)C3C(=O)O)c2ccccc2)C(=O)C1=O',
#   'CCN1CCN(C(=O)NC(C(=O)NC2C(=O)N3C2SC(C)(C)C3C(=O)O)c2ccccc2)C(=O)C1=O'),
#  ('CC1(C)SC2C(NC(=O)C(NC(=O)N3CCN(S(C)(=O)=O)C3=O)c3ccccc3)C(=O)N2C1C(=O)O',
#   'CC1(C)SC2C(NC(=O)C(NC(=O)N3CCN(S(C)(=O)=O)C3=O)c3ccccc3)C(=O)N2C1C(=O)O'),
#  ('CC1(C)SC2C(NC(=O)C(NC(=O)N3CCNC3=O)c3ccccc3)C(=O)N2C1C(=O)O',
#   'CC1(C)SC2C(NC(=O)C(NC(=O)N3CCNC3=O)c3ccccc3)C(=O)N2C1C(=O)O'),
#  ('CC1(C)SC2C(NC(=O)COc3ccccc3)C(=O)N2C1C(=O)O',
#   'CC1(C)SC2C(NC(=O)COc3ccccc3)C(=O)N2C1C(=O)O'),
#  ('CC1(C)SC2C(NC(=O)Cc3ccccc3)C(=O)N2C1C(=O)O',
#   'CC1(C)SC2C(NC(=O)Cc3ccccc3)C(=O)N2C1C(=O)O'),
#  ('COc1cccc(OC)c1C(=O)NC1C(=O)N2C1SC(C)(C)C2C(=O)O',
#   'COc1cccc(OC)c1C(=O)NC1C(=O)N2C1SC(C)(C)C2C(=O)O'),
#  ('Cc1onc(-c2ccccc2)c1C(=O)NC1C(=O)N2C1SC(C)(C)C2C(=O)O',
#   'Cc1onc(-c2ccccc2)c1C(=O)NC1C(=O)N2C1SC(C)(C)C2C(=O)O'),
#  ('CCOc1ccc2ccccc2c1C(=O)NC1C(=O)N2C1SC(C)(C)C2C(=O)O',
#   'CCOc1ccc2ccccc2c1C(=O)NC1C(=O)N2C1SC(C)(C)C2C(=O)O'),
#  ('Nc1nc(=O)n(C2CSC(CO)O2)cc1F', 'Nc1nc(=O)n(C2CSC(CO)O2)cc1F'),
#  ('Nc1ccn(C2CSC(CO)O2)c(=O)n1', 'Nc1ccn(C2CSC(CO)O2)c(=O)n1'),
#  ('O=C(O)CCCCC1SCC2NC(=O)NC21', 'O=C(O)CCCCC1SCC2NC(=O)NC21'),
#  ('CCOC(=O)c1ccc(C#Cc2ccc3c(c2)C(C)(C)CCS3)nc1',
#   'CCOC(=O)c1ccc(C#Cc2ccc3c(c2)C(C)(C)CCS3)nc1'),
#  ('c1ccc([C@H]2CN3CCSC3=N2)cc1', 'c1ccc([C@H]2CN3CCSC3=N2)cc1'),
#  ('CCC(C)C1NC(=O)C(Cc2ccc(O)cc2)NC(=O)C(N)CSSCC(C(=O)N2CCCC2C(=O)NC(CC(C)C)C(=O)NCC(N)=O)NC(=O)C(CC(N)=O)NC(=O)C(CCC(N)=O)NC1=O',
#   'CCC(C)C1NC(=O)C(Cc2ccc(O)cc2)NC(=O)C(N)CSSCC(C(=O)N2CCCC2C(=O)NC(CC(C)C)C(=O)NCC(N)=O)NC(=O)C(CC(N)=O)NC(=O)C(CCC(N)=O)NC1=O'),
#  ('CC(C)C1NC(=O)C(CCCCN)NC(=O)C(Cc2c[nH]c3ccccc23)NC(=O)C(Cc2ccc(O)cc2)NC(=O)C(NC(=O)C(N)Cc2ccc3ccccc3c2)CSSCC(C(=O)NC(C(N)=O)C(C)O)NC1=O',
#   'CC(C)C1NC(=O)C(CCCCN)NC(=O)C(Cc2c[nH]c3ccccc23)NC(=O)C(Cc2ccc(O)cc2)NC(=O)C(NC(=O)C(N)Cc2ccc3ccccc3c2)CSSCC(C(=O)NC(C(N)=O)C(C)O)NC1=O'),
#  ('CC(O)C(CO)NC(=O)C1CSSCC(NC(=O)C(N)Cc2ccccc2)C(=O)NC(Cc2ccccc2)C(=O)NC(Cc2c[nH]c3ccccc23)C(=O)NC(CCCCN)C(=O)NC(C(C)O)C(=O)N1',
#   'CC(O)C(CO)NC(=O)C1CSSCC(NC(=O)C(N)Cc2ccccc2)C(=O)NC(Cc2ccccc2)C(=O)NC(Cc2c[nH]c3ccccc23)C(=O)NC(CCCCN)C(=O)NC(C(C)O)C(=O)N1'),
#  ('N=C(N)NCCCCC1NC(=O)CCSSCC(C(N)=O)NC(=O)C2CCCN2C(=O)C(Cc2c[nH]c3ccccc23)NC(=O)C(CC(=O)O)NC(=O)CNC1=O',
#   'N=C(N)NCCCCC1NC(=O)CCSSCC(C(N)=O)NC(=O)C2CCCN2C(=O)C(Cc2c[nH]c3ccccc23)NC(=O)C(CC(=O)O)NC(=O)CNC1=O'),
#  ('CO/N=C(/C(=O)N[C@@H]1C(=O)N2C(C(=O)O)=C(COC(N)=O)CS[C@H]12)c1ccco1',
#   'CO/N=C(/C(=O)N[C@@H]1C(=O)N2C(C(=O)O)=C(COC(N)=O)CS[C@H]12)c1ccco1'),
#  ('CCN1CCN(C(=O)N[C@@H](C(=O)N[C@@H]2C(=O)N3C(C(=O)O)=C(CSc4nnnn4C)CS[C@H]23)c2ccc(O)cc2)C(=O)C1=O',
#   'CCN1CCN(C(=O)N[C@@H](C(=O)N[C@@H]2C(=O)N3C(C(=O)O)=C(CSc4nnnn4C)CS[C@H]23)c2ccc(O)cc2)C(=O)C1=O'),
#  ('Cn1nnnc1SCC1=C(C(=O)O)N2C(=O)[C@@H](NC(=O)[C@H](O)c3ccccc3)[C@H]2SC1',
#   'Cn1nnnc1SCC1=C(C(=O)O)N2C(=O)[C@@H](NC(=O)[C@H](O)c3ccccc3)[C@H]2SC1'),
#  ('O=C(O)C1=C(CSc2nnnn2CS(=O)(=O)O)CS[C@@H]2[C@H](NC(=O)[C@H](O)c3ccccc3)C(=O)N12',
#   'O=C(O)C1=C(CSc2nnnn2CS(=O)(=O)O)CS[C@@H]2[C@H](NC(=O)[C@H](O)c3ccccc3)C(=O)N12'),
#  ('C/C=C/C1=C(C(=O)O)N2C(=O)[C@@H](NC(=O)[C@H](N)c3ccc(O)cc3)[C@H]2SC1',
#   'C/C=C/C1=C(C(=O)O)N2C(=O)[C@@H](NC(=O)[C@H](N)c3ccc(O)cc3)[C@H]2SC1'),
#  ('COc1cc2c(cc1O)CCN[C@]21CS[C@@H]2c3c(OC(C)=O)c(C)c4c(c3[C@H](COC1=O)N1[C@@H](O)[C@@H]3Cc5cc(C)c(OC)c(O)c5[C@H]([C@H]21)N3C)OCO4',
#   'COc1cc2c(cc1O)CCN[C@]21CS[C@@H]2c3c(OC(C)=O)c(C)c4c(c3[C@H](COC1=O)N1[C@@H](O)[C@@H]3Cc5cc(C)c(OC)c(O)c5[C@H]([C@H]21)N3C)OCO4'),
#  ('CC(=O)/N=c1\\sc(S(N)(=O)=O)nn1C', 'CC(=O)/N=c1\\sc(S(N)(=O)=O)nn1C'),
#  ('CO[C@@]1(NC(=O)C2SC(=C(C(N)=O)C(=O)O)S2)C(=O)N2C(C(=O)O)=C(CSc3nnnn3C)CSC21',
#   'CO[C@@]1(NC(=O)C2SC(=C(C(N)=O)C(=O)O)S2)C(=O)N2C(C(=O)O)=C(CSc3nnnn3C)CSC21'),
#  ('CCN(CC)CCNc1ccc(CO)c2sc3ccccc3c(=O)c12',
#   'CCN(CC)CCNc1ccc(CO)c2sc3ccccc3c(=O)c12'),
#  ('CCOC(=O)Nc1ccc2c(c1)N(C(=O)CCN1CCOCC1)c1ccccc1S2',
#   'CCOC(=O)Nc1ccc2c(c1)N(C(=O)CCN1CCOCC1)c1ccccc1S2'),
#  ('CC(CN1c2ccccc2Sc2ccccc21)N(C)C', 'CC(CN1c2ccccc2Sc2ccccc21)N(C)C'),
#  ('CSc1ccc2c(c1)N(CCC1CCCCN1C)c1ccccc1S2',
#   'CSc1ccc2c(c1)N(CCC1CCCCN1C)c1ccccc1S2'),
#  ('CN(C)CCCN1c2ccccc2Sc2ccccc21', 'CN(C)CCCN1c2ccccc2Sc2ccccc21'),
#  ('CN1CCN(CCCN2c3ccccc3Sc3ccc(C(F)(F)F)cc32)CC1',
#   'CN1CCN(CCCN2c3ccccc3Sc3ccc(C(F)(F)F)cc32)CC1'),
#  ('OCCN1CCN(CCCN2c3ccccc3Sc3ccc(C(F)(F)F)cc32)CC1',
#   'OCCN1CCN(CCCN2c3ccccc3Sc3ccc(C(F)(F)F)cc32)CC1'),
#  ('c1ccc2c(c1)Nc1ccccc1S2', 'c1ccc2c(c1)Nc1ccccc1S2'),
#  ('CN1CCN(CC/C=C2/c3ccccc3Sc3ccc(S(=O)(=O)N(C)C)cc32)CC1',
#   'CN1CCN(CC/C=C2/c3ccccc3Sc3ccc(S(=O)(=O)N(C)C)cc32)CC1'),
#  ('OCCN1CCN(CC/C=C2/c3ccccc3Sc3ccc(C(F)(F)F)cc32)CC1',
#   'OCCN1CCN(CC/C=C2/c3ccccc3Sc3ccc(C(F)(F)F)cc32)CC1'),
#  ('OCCOCCN1CCN(C2=Nc3ccccc3Sc3ccccc32)CC1',
#   'OCCOCCN1CCN(C2=Nc3ccccc3Sc3ccccc32)CC1'),
#  ('COc1ccc2c(C(=S)N(C)CC(=O)O)cccc2c1C(F)(F)F',
#   'COc1ccc2c(C(=S)N(C)CC(=O)O)cccc2c1C(F)(F)F'),
#  ('CCc1cc(C(N)=S)ccn1', 'CCc1cc(C(N)=S)ccn1'),
#  ('CCOC(=O)n1ccn(C)c1=S', 'CCOC(=O)n1ccn(C)c1=S'),
#  ('Nc1nc(=S)c2[nH]cnc2[nH]1', 'Nc1nc(=S)c2[nH]cnc2[nH]1'),
#  ('S=c1nc[nH]c2nc[nH]c12', 'S=c1nc[nH]c2nc[nH]c12'),
#  ('CCCc1cc(=O)[nH]c(=S)[nH]1', 'CCCc1cc(=O)[nH]c(=S)[nH]1'),
#  ('Cn1cc[nH]c1=S', 'Cn1cc[nH]c1=S'),
#  ('S=C=Nc1cccc2ccccc12', 'S=C=Nc1cccc2ccccc12'),
#  ('S=P(N1CC1)(N1CC1)N1CC1', 'S=P(N1CC1)(N1CC1)N1CC1'),
#  ('CC(C)(S)C(N)C(=O)O', 'CC(C)(S)C(N)C(=O)O'),
#  ('O=C(O)C(S)C(S)C(=O)O', 'O=C(O)C(S)C(S)C(=O)O'),
#  ('OCC(S)CS', 'OCC(S)CS'),
#  ('CC(CS)C(=O)N1CCCC1C(=O)O', 'CC(CS)C(=O)N1CCCC1C(=O)O'),
#  ('CC(=O)NC(CS)C(=O)O', 'CC(=O)NC(CS)C(=O)O'),
#  ('NCCS', 'NCCS'),
#  ('Nc1cc(N2CCCCC2)nc(N)[n+]1[O-]', 'Nc1cc(N2CCCCC2)nc(N)[n+]1[O-]'),
#  ('Cc1c(N)nc([C@H](CC(N)=O)NC[C@H](N)C(N)=O)nc1C(=O)N[C@H](C(=O)N[C@H](C)[C@@H](O)[C@H](C)C(=O)N[C@H](C(=O)NCCc1nc(-c2nc(C(=O)NCCC[S+](C)C)cs2)cs1)[C@@H](C)O)[C@@H](O[C@@H]1O[C@H](CO)[C@H](O)[C@@H](O)[C@H]1O[C@H]1O[C@H](CO)[C@@H](O)[C@@H](OC(=N)[O-])[C@H]1O)c1cnc[nH]1',
#   'Cc1c(N)nc([C@H](CC(N)=O)NC[C@H](N)C(N)=O)nc1C(=O)N[C@H](C(=O)N[C@H](C)[C@@H](O)[C@H](C)C(=O)N[C@H](C(=O)NCCc1nc(-c2nc(C(=O)NCCC[S+](C)C)cs2)cs1)[C@@H](C)O)[C@@H](O[C@@H]1O[C@H](CO)[C@H](O)[C@@H](O)[C@H]1O[C@H]1O[C@H](CO)[C@@H](O)[C@@H](OC(=N)[O-])[C@H]1O)c1cnc[nH]1'),
#  ('CN(C)CCc1c[nH]c2ccc(Cn3cncn3)cc12', 'CN(C)CCc1c[nH]c2ccc(Cn3cncn3)cc12'),
#  ('Cc1cccc(C(C)c2cnc[nH]2)c1C', 'Cc1cccc(C(C)c2cnc[nH]2)c1C'),
#  ('Cc1ccccc1N1CCN(CCc2nnc3n2CCCC3)CC1', 'Cc1ccccc1N1CCN(CCc2nnc3n2CCCC3)CC1'),
#  ('Nc1ccc(N=Nc2ccccc2)c(N)n1', 'Nc1ccc(N=Nc2ccccc2)c(N)n1'),
#  ('Nc1nc(N)c2nc(-c3ccccc3)c(N)nc2n1', 'Nc1nc(N)c2nc(-c3ccccc3)c(N)nc2n1'),
#  ('CN(C)c1nc(N(C)C)nc(N(C)C)n1', 'CN(C)c1nc(N(C)C)nc(N(C)C)n1'),
#  ('CN1CCC(=C2c3ccccc3CCc3cccnc32)CC1', 'CN1CCC(=C2c3ccccc3CCc3cccnc32)CC1'),
#  ('CN1CCN2c3ncccc3Cc3ccccc3C2C1', 'CN1CCN2c3ncccc3Cc3ccccc3C2C1'),
#  ('CC(C)Cn1cnc2c(N)nc3ccccc3c21', 'CC(C)Cn1cnc2c(N)nc3ccccc3c21'),
#  ('CN1CCCC1c1cccnc1', 'CN1CCCC1c1cccnc1'),
#  ('CC(/N=C(\\NC#N)Nc1ccncc1)C(C)(C)C', 'CC(/N=C(\\NC#N)Nc1ccncc1)C(C)(C)C'),
#  ('CNCCc1ccccn1', 'CNCCc1ccccn1'),
#  ('CN(C)CCN(Cc1ccccc1)c1ccccn1', 'CN(C)CCN(Cc1ccccc1)c1ccccn1'),
#  ('CC(C)Nc1ncccn1', 'CC(C)Nc1ncccn1'),
#  ('N#Cc1ccc(C(c2ccc(C#N)cc2)n2cncn2)cc1',
#   'N#Cc1ccc(C(c2ccc(C#N)cc2)n2cncn2)cc1'),
#  ('CC(C)(C#N)c1cc(Cn2cncn2)cc(C(C)(C)C#N)c1',
#   'CC(C)(C#N)c1cc(Cn2cncn2)cc(C(C)(C)C#N)c1'),
#  ('NNc1nncc2ccccc12', 'NNc1nncc2ccccc12'),
#  ('O=C(O)CCc1nc(-c2ccccc2)c(-c2ccccc2)o1',
#   'O=C(O)CCc1nc(-c2ccccc2)c(-c2ccccc2)o1'),
#  ('O=C1CN(/N=C/c2ccc([N+](=O)[O-])o2)C(=O)N1',
#   'O=C1CN(/N=C/c2ccc([N+](=O)[O-])o2)C(=O)N1'),
#  ('O=C1CN(/N=C/c2ccc(-c3ccc([N+](=O)[O-])cc3)o2)C(=O)N1',
#   'O=C1CN(/N=C/c2ccc(-c3ccc([N+](=O)[O-])cc3)o2)C(=O)N1'),
#  ('CCc1oc2ccccc2c1C(=O)c1ccc(O)cc1', 'CCc1oc2ccccc2c1C(=O)c1ccc(O)cc1'),
#  ('COc1cc2nc(N3CCN(C(=O)c4ccco4)CC3)nc(N)c2cc1OC',
#   'COc1cc2nc(N3CCN(C(=O)c4ccco4)CC3)nc(N)c2cc1OC'),
#  ('Cc1cc(C(=O)NNCc2ccccc2)no1', 'Cc1cc(C(=O)NNCc2ccccc2)no1'),
#  ('COC(=O)C1=C(C)NC(C)=C(C(=O)OC(C)C)C1c1cccc2nonc12',
#   'COC(=O)C1=C(C)NC(C)=C(C(=O)OC(C)C)C1c1cccc2nonc12'),
#  ('C#C[C@]1(O)CCC2C3CCC4=Cc5oncc5C[C@]4(C)C3CC[C@@]21C',
#   'C#C[C@]1(O)CCC2C3CCC4=Cc5oncc5C[C@]4(C)C3CC[C@@]21C'),
#  ('CC(=O)Oc1ccccc1C(=O)Nc1ncc([N+](=O)[O-])s1',
#   'CC(=O)Oc1ccccc1C(=O)Nc1ncc([N+](=O)[O-])s1'),
#  ('Cc1nc2ccc(CN(C)c3ccc(C(=O)NC(CCC(=O)O)C(=O)O)s3)cc2c(=O)[nH]1',
#   'Cc1nc2ccc(CN(C)c3ccc(C(=O)NC(CCC(=O)O)C(=O)O)s3)cc2c(=O)[nH]1'),
#  ('Cc1cnc(NC(=O)C2=C(O)c3ccccc3S(=O)(=O)N2C)s1',
#   'Cc1cnc(NC(=O)C2=C(O)c3ccccc3S(=O)(=O)N2C)s1'),
#  ('Cc1nnc(NS(=O)(=O)c2ccc(N)cc2)s1', 'Cc1nnc(NS(=O)(=O)c2ccc(N)cc2)s1'),
#  ('CC(=O)Nc1nnc(S(N)(=O)=O)s1', 'CC(=O)Nc1nnc(S(N)(=O)=O)s1'),
#  ('CCCNC1CCc2nc(N)sc2C1', 'CCCNC1CCc2nc(N)sc2C1'),
#  ('Cc1cc2c(s1)Nc1ccccc1N=C2N1CCN(C)CC1',
#   'Cc1cc2c(s1)Nc1ccccc1N=C2N1CCN(C)CC1'),
#  ('CCNC1CC(C)S(=O)(=O)c2sc(S(N)(=O)=O)cc21',
#   'CCNC1CC(C)S(=O)(=O)c2sc(S(N)(=O)=O)cc21'),
#  ('CCNC1CN(CCCOC)S(=O)(=O)c2sc(S(N)(=O)=O)cc21',
#   'CCNC1CN(CCCOC)S(=O)(=O)c2sc(S(N)(=O)=O)cc21'),
#  ('CN1CCC(=C2c3ccccc3CCc3sccc32)CC1', 'CN1CCC(=C2c3ccccc3CCc3sccc32)CC1'),
#  ('CN1CCC(=C2c3ccccc3CC(=O)c3sccc32)CC1',
#   'CN1CCC(=C2c3ccccc3CC(=O)c3sccc32)CC1'),
#  ('CC(c1cc2ccccc2s1)N(O)C(N)=O', 'CC(c1cc2ccccc2s1)N(O)C(N)=O'),
#  ('O=C(c1ccc(OCCN2CCCCC2)cc1)c1c(-c2ccc(O)cc2)sc2cc(O)ccc12',
#   'O=C(c1ccc(OCCN2CCCCC2)cc1)c1c(-c2ccc(O)cc2)sc2cc(O)ccc12'),
#  ('Nc1nc2ccc(OC(F)(F)F)cc2s1', 'Nc1nc2ccc(OC(F)(F)F)cc2s1'),
#  ('CCCNC(C)C(=O)Nc1c(C)csc1C(=O)OC', 'CCCNC(C)C(=O)Nc1c(C)csc1C(=O)OC'),
#  ('C/C(=C\\c1csc(C)n1)[C@@H]1C[C@@H]2O[C@]2(C)CCC[C@H](C)[C@H](O)[C@@H](C)C(=O)C(C)(C)[C@@H](O)CC(=O)N1',
#   'C/C(=C\\c1csc(C)n1)[C@@H]1C[C@@H]2O[C@]2(C)CCC[C@H](C)[C@H](O)[C@@H](C)C(=O)C(C)(C)[C@@H](O)CC(=O)N1'),
#  ('CN/C(=C\\[N+](=O)[O-])NCCSCc1csc(CN(C)C)n1',
#   'CN/C(=C\\[N+](=O)[O-])NCCSCc1csc(CN(C)C)n1'),
#  ('Nc1nc(/C(=C\\CC(=O)O)C(=O)N[C@@H]2C(=O)N3C(C(=O)O)=CCS[C@H]23)cs1',
#   'Nc1nc(/C(=C\\CC(=O)O)C(=O)N[C@@H]2C(=O)N3C(C(=O)O)=CCS[C@H]23)cs1'),
#  ('C=CC1=C(C(=O)O)N2C(=O)C(NC(=O)/C(=N\\O)c3csc(N)n3)C2SC1',
#   'C=CC1=C(C(=O)O)N2C(=O)C(NC(=O)/C(=N\\O)c3csc(N)n3)C2SC1'),
#  ('CC1C(NC(=O)/C(=N\\OC(C)(C)C(=O)O)c2csc(N)n2)C(=O)N1S(=O)(=O)O',
#   'CC1C(NC(=O)/C(=N\\OC(C)(C)C(=O)O)c2csc(N)n2)C(=O)N1S(=O)(=O)O'),
#  ('CC(C)(O/N=C(\\C(=O)NC1C(=O)N2C(C(=O)[O-])=C(C[n+]3ccccc3)CSC12)c1csc(N)n1)C(=O)O',
#   'CC(C)(O/N=C(\\C(=O)NC1C(=O)N2C(C(=O)[O-])=C(C[n+]3ccccc3)CSC12)c1csc(N)n1)C(=O)O'),
#  ('CO/N=C(\\C(=O)NC1C(=O)N2C(C(=O)O)=C(CSc3nc(=O)c(=O)[nH]n3C)CSC12)c1csc(N)n1',
#   'CO/N=C(\\C(=O)NC1C(=O)N2C(C(=O)O)=C(CSc3nc(=O)c(=O)[nH]n3C)CSC12)c1csc(N)n1'),
#  ('CO/N=C(\\C(=O)NC1C(=O)N2C(C(=O)O)=CCSC12)c1csc(N)n1',
#   'CO/N=C(\\C(=O)NC1C(=O)N2C(C(=O)O)=CCSC12)c1csc(N)n1'),
#  ('COCC1=C(C(=O)O)N2C(=O)[C@@H](NC(=O)/C(=N\\OC)c3csc(N)n3)[C@H]2SC1',
#   'COCC1=C(C(=O)O)N2C(=O)[C@@H](NC(=O)/C(=N\\OC)c3csc(N)n3)[C@H]2SC1'),
#  ('CO/N=C(\\C(=O)N[C@@H]1C(=O)N2C(C(=O)[O-])=C(C[N+]3(C)CCCC3)CS[C@H]12)c1csc(N)n1',
#   'CO/N=C(\\C(=O)N[C@@H]1C(=O)N2C(C(=O)[O-])=C(C[N+]3(C)CCCC3)CS[C@H]12)c1csc(N)n1'),
#  ('C=CC1=C(C(=O)O)N2C(=O)C(NC(=O)/C(=N\\OCC(=O)O)c3csc(N)n3)C2SC1',
#   'C=CC1=C(C(=O)O)N2C(=O)C(NC(=O)/C(=N\\OCC(=O)O)c3csc(N)n3)C2SC1'),
#  ('CN(C)CCn1nnnc1SCC1=C(C(=O)O)N2C(=O)C(NC(=O)Cc3csc(N)n3)C2SC1',
#   'CN(C)CCn1nnnc1SCC1=C(C(=O)O)N2C(=O)C(NC(=O)Cc3csc(N)n3)C2SC1'),
#  ('NC(N)=Nc1nc(CSCC/C(N)=N/S(N)(=O)=O)cs1',
#   'NC(N)=Nc1nc(CSCC/C(N)=N/S(N)(=O)=O)cs1'),
#  ('Cc1ccsc1C(=CCCN1CCCC(C(=O)O)C1)c1sccc1C',
#   'Cc1ccsc1C(=CCCN1CCCC(C(=O)O)C1)c1sccc1C'),
#  ('COC(=O)Nc1nc2ccc(C(=O)c3cccs3)cc2[nH]1',
#   'COC(=O)Nc1nc2ccc(C(=O)c3cccs3)cc2[nH]1'),
#  ('C[C@H](C(=O)O)c1ccc(C(=O)c2cccs2)cc1',
#   'C[C@H](C(=O)O)c1ccc(C(=O)c2cccs2)cc1'),
#  ('CNCCC(Oc1cccc2ccccc12)c1cccs1', 'CNCCC(Oc1cccc2ccccc12)c1cccs1'),
#  ('COc1cc(C2c3cc4c(cc3C(OC3OC5COC(c6cccs6)OC5C(O)C3O)C3COC(=O)C23)OCO4)cc(OC)c1O',
#   'COc1cc(C2c3cc4c(cc3C(OC3OC5COC(c6cccs6)OC5C(O)C3O)C3COC(=O)C23)OCO4)cc(OC)c1O'),
#  ('CC(=O)OCC1=C(C(=O)O)N2C(=O)C(NC(=O)Cc3cccs3)C2SC1',
#   'CC(=O)OCC1=C(C(=O)O)N2C(=O)C(NC(=O)Cc3cccs3)C2SC1'),
#  ('O=C(Cc1cccs1)NC1C(=O)N2C(C(=O)[O-])=C(C[n+]3ccccc3)CSC12',
#   'O=C(Cc1cccs1)NC1C(=O)N2C(C(=O)[O-])=C(C[n+]3ccccc3)CSC12'),
#  ('CO[C@@]1(NC(=O)Cc2cccs2)C(=O)N2C(C(=O)O)=C(COC(N)=O)CSC21',
#   'CO[C@@]1(NC(=O)Cc2cccs2)C(=O)N2C(C(=O)O)=C(COC(N)=O)CSC21'),
#  ('CCC(=O)N(c1ccccc1)C1(COC)CCN(CCc2cccs2)CC1',
#   'CCC(=O)N(c1ccccc1)C1(COC)CCN(CCc2cccs2)CC1'),
#  ('CN(C)CCN(Cc1cccs1)c1ccccn1', 'CN(C)CCN(Cc1cccs1)c1ccccn1'),
#  ('CCCCc1ncc(/C=C(\\Cc2cccs2)C(=O)O)n1Cc1ccc(C(=O)O)cc1',
#   'CCCCc1ncc(/C=C(\\Cc2cccs2)C(=O)O)n1Cc1ccc(C(=O)O)cc1'),
#  ('CN1CCCN=C1/C=C/c1cccs1', 'CN1CCCN=C1/C=C/c1cccs1'),
#  ('CN1C(C(=O)Nc2nccs2)=C(O)c2ccccc2S1(=O)=O',
#   'CN1C(C(=O)Nc2nccs2)=C(O)c2ccccc2S1(=O)=O'),
#  ('CC(C)c1nc(CN(C)C(=O)NC(C(=O)NC(Cc2ccccc2)CC(O)C(Cc2ccccc2)NC(=O)OCc2cncs2)C(C)C)cs1',
#   'CC(C)c1nc(CN(C)C(=O)NC(C(=O)NC(Cc2ccccc2)CC(O)C(Cc2ccccc2)NC(=O)OCc2cncs2)C(C)C)cs1')]

# %% [markdown]
# We clean up the similes strings into stuff that can be fed into the LSTM
# #use content from https://pytorch.org/tutorials/intermediate/seq2seq_translation_tutorial.html

# %% [markdown]
# useful loss_function = nn.CrossEntropyLoss(ignore_index=0)

# %%
PAD_token = 0
SOS_token = 1
EOS_token = 2

class Lang:
    def __init__(self, name):
        self.name = name
        self.char2index = {}
        self.char2count = {}
        self.index2char = {0: "PAD", 1: "SOS", 2: "EOS"}
        self.n_chars = 3  # Count SOS and EOS and PAD

    def addSMILES(self, smiles):
        for char in smiles:
            self.addChar(char)

    def addChar(self, char):
        if char not in self.char2index:
            self.char2index[char] = self.n_chars
            self.char2count[char] = 1
            self.index2char[self.n_chars] = char
            self.n_chars += 1
        else:
            self.char2count[char] += 1

# %% [markdown]
# max([len(smiles) for smiles in traindata['SMILES'] ]) = 297

# %% [markdown]
# max([len(smiles) for smiles in traindata['cleanSMILES'] ]) = 293

# %%
MIN_LENGTH = 3
MAX_LENGTH = 25

def filter_pairs(pairs):
    filtered_pairs = []
    for pair in pairs:
        if len(pair[0]) >= MIN_LENGTH and len(pair[0]) <= MAX_LENGTH \
            and len(pair[1]) >= MIN_LENGTH and len(pair[1]) <= MAX_LENGTH:
                filtered_pairs.append(pair)
    return filtered_pairs

# %%
def prepareData(lang1, lang2, data):
    """takes data as list of pairs for now
    returns the dictionaries for input and output languages, and the pairs"""
    input_lang = Lang(lang1)
    output_lang = Lang(lang2)
    pairs = data
    print("Read %s smiles pairs" % len(pairs))
    
    pairs = filter_pairs(pairs)
    print("Filtered to %d pairs" % len(pairs))
    
    print("Counting chars...")
    for pair in pairs:
        input_lang.addSMILES(pair[0])
        output_lang.addSMILES(pair[1])
    print("Counted chars:")
    print(input_lang.name, input_lang.n_chars)
    print(output_lang.name, output_lang.n_chars)
    return input_lang, output_lang, pairs

# %%
#input_lang, output_lang, pairs = prepareData("Random SMILES","Canonical SMILES", data)
input_lang, output_lang, pairs = prepareData("Canonical SMILES","Canonical SMILES", identitydata)
print(random.choice(pairs))
# Out:
# Read 966 smiles pairs
# Filtered to 143 pairs
# Counting chars...
# Counted chars:
# Canonical SMILES 30
# Canonical SMILES 30
# ('NC(=O)c1cnccn1', 'NC(=O)c1cnccn1')

# %%
input_lang

# %% [markdown]
# Now we implement the seq-to-vec part

# %%
class EncoderRNN(nn.Module):
    """what is
    input size - number of different characters that can be in a smiles string
    hidden size
    """
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        #first dim is batch size
        #second dim is seq len?? or other way around?
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
class DecoderRNN(nn.Module):
    """output size: number of chars in canonical smiles language"""
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        output = self.embedding(input).view(1, 1, -1)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
def indexesFromSmiles(lang, smiles):
    return [lang.char2index[char] for char in smiles] + [EOS_token]


def tensorFromSmiles(lang, smiles):
    indexes = indexesFromSmiles(lang, smiles)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)

def pad_seq(seq, max_length):
    seq += [PAD_token for i in range(max_length - len(seq))]
    return seq

# %%
def random_batch(batch_size):
    input_seqs = []
    target_seqs = []

    # Choose random pairs
    for i in range(batch_size):
        pair = random.choice(pairs)
        input_seqs.append(indexesFromSmiles(input_lang, pair[0]))
        target_seqs.append(indexesFromSmiles(output_lang, pair[1]))

    # Zip into pairs, sort by length (descending), unzip
    seq_pairs = sorted(zip(input_seqs, target_seqs), key=lambda p: len(p[0]), reverse=True)
    input_seqs, target_seqs = zip(*seq_pairs) 
    """the * unzips"""
    
    # For input and target sequences, get array of lengths and pad with 0s to max length
    input_lengths = [len(s) for s in input_seqs]
    input_padded = [pad_seq(s, max(input_lengths)) for s in input_seqs]
    target_lengths = [len(s) for s in target_seqs]
    target_padded = [pad_seq(s, max(target_lengths)) for s in target_seqs]

    # Turn padded arrays into (batch_size x max_len) tensors, transpose into (max_len x batch_size)
    input_var = Variable(torch.LongTensor(input_padded)).transpose(0, 1)
    target_var = Variable(torch.LongTensor(target_padded)).transpose(0, 1)
    
    if USE_CUDA:
        input_var = input_var.cuda()
        target_var = target_var.cuda()
        
    return input_var, input_lengths, target_var, target_lengths

# %%
random_batch(2)
# Out:
# (tensor([[ 4, 10],
#          [13, 11],
#          [ 5, 10],
#          [ 4, 10],
#          [ 6, 10],
#          [13,  5],
#          [14,  4],
#          [13,  4],
#          [10, 20],
#          [11, 14],
#          [16, 13],
#          [17,  4],
#          [18,  4],
#          [19, 13],
#          [10, 20],
#          [17,  6],
#          [10, 10],
#          [11, 10],
#          [ 4, 11],
#          [ 5,  2],
#          [13,  0],
#          [ 6,  0],
#          [14,  0],
#          [12,  0],
#          [ 2,  0]]),
#  [25, 20],
#  tensor([[ 4, 10],
#          [13, 11],
#          [ 5, 10],
#          [ 4, 10],
#          [ 6, 10],
#          [13,  5],
#          [14,  4],
#          [13,  4],
#          [10, 20],
#          [11, 14],
#          [16, 13],
#          [17,  4],
#          [18,  4],
#          [19, 13],
#          [10, 20],
#          [17,  6],
#          [10, 10],
#          [11, 10],
#          [ 4, 11],
#          [ 5,  2],
#          [13,  0],
#          [ 6,  0],
#          [14,  0],
#          [12,  0],
#          [ 2,  0]]),
#  [25, 20])

# %%
indexesFromSmiles(input_lang, 'CCCO')
# Out:
# [4, 4, 4, 12, 2]

# %%
tensorsFromPair(pairs[0])
# Out:
# (tensor([[3],
#          [4],
#          [5],
#          [3],
#          [6],
#          [5],
#          [3],
#          [6],
#          [4],
#          [5],
#          [4],
#          [7],
#          [6],
#          [8],
#          [9],
#          [2]]),
#  tensor([[3],
#          [4],
#          [5],
#          [3],
#          [6],
#          [5],
#          [3],
#          [6],
#          [4],
#          [5],
#          [4],
#          [7],
#          [6],
#          [8],
#          [9],
#          [2]]))

# %%
output_lang.char2index
# Out:
# {'F': 3,
#  'C': 4,
#  '(': 5,
#  ')': 6,
#  'l': 7,
#  'B': 8,
#  'r': 9,
#  'c': 10,
#  '1': 11,
#  'O': 12,
#  'N': 13,
#  '=': 14,
#  'P': 15,
#  '[': 16,
#  'n': 17,
#  'H': 18,
#  ']': 19,
#  '2': 20,
#  'o': 21,
#  's': 22,
#  '#': 23,
#  '@': 24,
#  '3': 25,
#  '+': 26,
#  '-': 27,
#  'S': 28,
#  '/': 29}

# %%
teacher_forcing_ratio = 0.5


def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer,\
          decoder_optimizer, criterion, max_length=MAX_LENGTH+1):
    """This trains on a single smiles string
    We added +1 to max length to account for the extra EOS token added"""
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input
            """What is history? why not use topi.item?"""
            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %%
def trainMinibatch(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder,
                     decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %%
def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder,
                     decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %%
def evaluate(encoder, decoder, smiles, max_length=MAX_LENGTH+1):
    with torch.no_grad():
        input_tensor = tensorFromSmiles(input_lang, smiles)
        #print("\nInput tensor shape: ", input_tensor.shape)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()
        #print("\nencoder hidden shape: ", encoder_hidden.shape)

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)
        #print("\nencoder outputs shape: ", encoder_outputs.shape)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_chars = []
        #decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            #decoder_output, decoder_hidden, decoder_attention = decoder(\
            #decoder_input, decoder_hidden, encoder_outputs)
            #we dont care about encoder outputs, lets see what happens
            decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden)
            #decoder_attentions[di] = decoder_attention.data
            #print("decoder output shape: ",decoder_output.shape)
            #print("decoder output: ",decoder_output)
            topv, topi = decoder_output.data.topk(1)
            #print("topv: ",topv) 
            """topv is the largest component of decoder output (which is a softmax) over the 37 
            characters in can smiles lang, topi is its index"""
            #print("topi: ",topi)
            if topi.item() == EOS_token:
                decoded_chars.append('<EOS>')
                break
            else:
                decoded_chars.append(output_lang.index2char[topi.item()])

            decoder_input = topi.squeeze().detach()

        return ''.join(decoded_chars)

# %%
def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('original smiles', pair[0])
        print('actual canonical SMILES', pair[1])
        output_smiles = evaluate(encoder, decoder, pair[0])
        print('predicted canonical SMILES', output_smiles)
        print('')

# %% [markdown]
# # Actual training

# %% [markdown]
# ## Loading a saved model

# %%
hidden_size = 512
encoder1 = EncoderRNN(input_lang.n_chars, hidden_size).to(device)
decoder1 = DecoderRNN(hidden_size, output_lang.n_chars).to(device)

from pathlib import Path
savedencoderfile = "SMILESencoder512.pt"
saveddecoderfile = "SMILESdecoder512.pt"
if Path(savedencoderfile).is_file():
    # file exists
    encoder1.load_state_dict(torch.load(savedencoderfile))
    #model.eval() wtf is this
    print("=== Encoder was loaded from " + savedencoderfile)
    
if Path(saveddecoderfile).is_file():
    # file exists
    decoder1.load_state_dict(torch.load(saveddecoderfile))
    #model.eval() wtf is this
    print("=== Decoder was loaded from " + saveddecoderfile)

# %%
evaluate(encoder1, decoder1, 'CCCOC')
# Out:
# '++++++++++++++++++++++++++'

# %%
trainIters(encoder1, decoder1, 1000, print_every=50)

torch.save(encoder1.state_dict(), savedencoderfile)
torch.save(decoder1.state_dict(), saveddecoderfile)
print("Model was saved as ",savedencoderfile, "and", saveddecoderfile )
# Out:
# 0m 15s (- 4m 51s) (50 5%) 3.7732
# 0m 30s (- 4m 31s) (100 10%) 4.2031
# 0m 46s (- 4m 22s) (150 15%) 5.4111
# 1m 0s (- 4m 2s) (200 20%) 2.5326
# 1m 14s (- 3m 42s) (250 25%) 2.1887
# 1m 30s (- 3m 30s) (300 30%) 2.2339
# 1m 47s (- 3m 19s) (350 35%) 1.9548
# 2m 2s (- 3m 4s) (400 40%) 1.9077
# 2m 18s (- 2m 49s) (450 45%) 1.7853
# 2m 36s (- 2m 36s) (500 50%) 2.0057
# 2m 50s (- 2m 19s) (550 55%) 1.8321
# 3m 3s (- 2m 2s) (600 60%) 1.6831
# 3m 18s (- 1m 46s) (650 65%) 1.6905
# 3m 33s (- 1m 31s) (700 70%) 1.7059
# 3m 48s (- 1m 16s) (750 75%) 1.7167
# 4m 2s (- 1m 0s) (800 80%) 1.7275
# 4m 18s (- 0m 45s) (850 85%) 1.5289
# 4m 33s (- 0m 30s) (900 90%) 1.7386
# 4m 48s (- 0m 15s) (950 95%) 1.9763
# 5m 2s (- 0m 0s) (1000 100%) 1.8370
# Model was saved as  SMILESencoder512.pt and SMILESdecoder512.pt

# %%
evaluateRandomly(encoder1, decoder1)
# Out:
# original smiles C1N2CN3CN1CN(C2)C3
# actual canonical SMILES C1N2CN3CN1CN(C2)C3
# predicted canonical SMILES NC1CC2C(C)CC<EOS>
#
# original smiles Nc1nc(=S)c2[nH]cnc2[nH]1
# actual canonical SMILES Nc1nc(=S)c2[nH]cnc2[nH]1
# predicted canonical SMILES Nc1ncccccccccc2cccc<EOS>
#
# original smiles C[N+](C)(C)CCOC(=N)[O-]
# actual canonical SMILES C[N+](C)(C)CCOC(=N)[O-]
# predicted canonical SMILES CCCC[NC+](C)CC(=O)NC<EOS>
#
# original smiles O=P1(NCCCl)OCCCN1CCCl
# actual canonical SMILES O=P1(NCCCl)OCCCN1CCCl
# predicted canonical SMILES N=NCC(=O)NCC1=O<EOS>
#
# original smiles CC(=O)Nc1ccc(O)cc1
# actual canonical SMILES CC(=O)Nc1ccc(O)cc1
# predicted canonical SMILES CC(C)cccccccccccc)cc<EOS>
#
# original smiles O=NN(CCCl)C(=O)NC1CCCCC1
# actual canonical SMILES O=NN(CCCl)C(=O)NC1CCCCC1
# predicted canonical SMILES N=NN(=O)NC1=O<EOS>
#
# original smiles Nc1nc(=O)[nH]cc1F
# actual canonical SMILES Nc1nc(=O)[nH]cc1F
# predicted canonical SMILES Ncccccccccccc1ccccc<EOS>
#
# original smiles CC(=O)Nc1ccc(O)cc1
# actual canonical SMILES CC(=O)Nc1ccc(O)cc1
# predicted canonical SMILES CC(C)cccccccccccc)cc<EOS>
#
# original smiles CC(C)(N)Cc1ccccc1
# actual canonical SMILES CC(C)(N)Cc1ccccc1
# predicted canonical SMILES CC(C)c1cccccccc1<EOS>
#
# original smiles CNCC(O)c1ccc(O)c(O)c1
# actual canonical SMILES CNCC(O)c1ccc(O)c(O)c1
# predicted canonical SMILES CCC(C)cccccccccccc)ccc<EOS>

# %% [markdown]
# # Saving the model

# %%
torch.save(encoder1.state_dict(), savedencoderfile)
torch.save(decoder1.state_dict(), saveddecoderfile)
print("Model was saved as ",savedencoderfile, "and", saveddecoderfile )
# Out:
# Model was saved as  SMILESencoder.pt and SMILESdecoder.pt

# %% [markdown]
# https://github.com/spro/practical-pytorch/blob/master/seq2seq-translation/seq2seq-translation-batched.ipynb

# %%
#################################
class Model_RNN(nn.Module):
    def __init__(self):
        super(Model_RNN, self).__init__()
        self.rnn = nn.RNN(
                input_size = input_size,
                hidden_size = hidden_size,
                num_layers = num_layers,
                batch_first = True)
        self.Rnn_type = 'RNN'

    def forward(self, x, hidden):
        # Reshape input in (bs, seqlen, inpsz)
        x = x.view(batch_size, seq_len, input_size)

        # Propagete inp thru RNN
        #   Input: (batchsz, seq_len, inpsz)
        out, hidden = self.rnn(x, hidden)

        # Output: (batchsz, seq_len, hiddensz)
        out = out.view(-1, num_classes)
        return hidden, out

    def init_hidden(self):
        # Init hidden and cell states
        # (num_layers * num_dir, batch, hidden_sz)
        return Variable(torch.zeros(num_layers, batch_size, hidden_size))

class Model_LSTM(nn.Module):
    def __init__(self):
        super(Model_LSTM, self).__init__()
        self.rnn = nn.LSTM(
                input_size = input_size,
                hidden_size = hidden_size,
                num_layers = num_layers,
                batch_first = True)
        self.Rnn_type = 'LSTM'

    def forward(self, x, hidden):
        # Reshape input in (bs, seqlen, inpsz)
        x = x.view(batch_size, seq_len, input_size)

        # Propagete inp thru RNN
        #   Input: (batchsz, seq_len, inpsz)
        out, hidden = self.rnn(x, hidden)

        # Output: (batchsz, seq_len, hiddensz)
        out = out.view(-1, num_classes)
        return hidden, out

    def init_hidden(self):
        # Init hidden and cell states
        # (num_layers * num_dir, batch, hidden_sz)
        # LSTM hidden state is a tuple (h_0, c_0)
        h_0 = Variable(torch.zeros(num_layers, batch_size, hidden_size))
        c_0 = Variable(torch.zeros(num_layers, batch_size, hidden_size))
        hidden = (h_0, c_0)
        return hidden

#################################

Inp_size = len(Inp_alphabet)
Out_size = len(Out_alphabet)
torch.manual_seed(2.7321)

#################################
num_classes = Out_size          #  XXX why need a separate num_classes,  when hidden_size would do?
input_size = Inp_size  # this parameter is for the view function to know how large
#the one hot vector is supposed to be

hidden_size = Out_size #
batch_size = 1   # id dont understand this
seq_len = Seq_max
num_layers = Arg_num_layers  # num-layers of rnn
#learning_rate = 0.01
momentum = 0.1


############## Model Training code ##########################
def train_phase():
    global Optimizer
    MIN_LOSS = float('inf')
    MIN_LOSS_epoch_counter = 0
    MAX_ACC_epoch_counter = 0

    final_train_epoch=0
    final_train_accuracy=0

    for epoch in range(max_epochs):
        Optimizer.zero_grad()
        loss = 0
        errcount = 0
        # if epoch % 30 ==0:
        #     evaluate_model(inputs,labels)
        for input, label in zip(Inputs, Labels):
            # input = input.unsqueeze(0)
            hidden = model.init_hidden() #we reset the RNN to its initial state
            hidden, output = model(input, hidden) #run the model

            val, idx = output.max(1)
            expected = decode_out(label)
            trained = decode_out(idx)

            if trained != expected:
                errcount += 1

            if epoch % vizdelay == 0:
                if (trained != expected):
                    print("check : ", decode_inp(input), " -> expected: ", expected, "        predicted: ", trained, "   *****")
                else:
                    print("check : ", decode_inp(input), " -> expected: ", expected, "        predicted: ", trained)
            loss += Criterion(output, label) #add the current sample error to loss

        loss.backward()
        Optimizer.step()

        ########### Within loop plotting and logging ########
        if loss.data < MIN_LOSS:
            MIN_LOSS = loss.data
            MIN_LOSS_epoch_counter = epoch   # reset

        accuracy = 100.0 * (Num_io_data - errcount) / Num_io_data
        print("Epoch: %d, loss: %1.3f         errcount: %d  accuracy: %1.1f%%\n" % (epoch+1, loss.data, errcount, accuracy))
        print("-------------------------------------------")

        plot_data.append([loss.data.item(), accuracy])
        t = [ x for x in range(0, epoch)]
        p = np.array(plot_data)
        plt_ax1.plot(p[:, 0], color='red')
        plt_ax2.plot(p[:, 1], color='blue')
        plt.pause(0.001)
        #plt.show()

        final_train_epoch = epoch
        final_train_accuracy = accuracy
        if BREAK_EARLY == True:
            global Train_end_reason
            if (epoch - MIN_LOSS_epoch_counter) >= 20:
                Train_end_reason = "=== no new low of training_loss seen for last 20 epochs; stop training"
                print(Train_end_reason)
                break

            if accuracy >= 99.9:
                MAX_ACC_epoch_counter += 1
                # stop, if accuracy stays at ~100 for 10 epochs
                if MAX_ACC_epoch_counter >= 10:
                    Train_end_reason = "=== maximal accuracy seen for last 10 epochs; stop training"
                    print(Train_end_reason)
                    time.sleep(4)
                    break

        # update optimizer with changed lr - depending on accuracy
        Optimizer = get_new_optimizer(learning_rate, accuracy)
    return final_train_accuracy, final_train_epoch


####################### Model evaluation code ################
def evaluate_model_1(xdata, ydata):
    x_one_hot = simple_to_onehot(xdata, Inp_alphabet)
    inputs = Variable(torch.Tensor(x_one_hot))
    labels = Variable(torch.LongTensor(ydata))

    err_count = 0
    for input, label in zip(inputs, labels):
        expected = decode_out(label)
        hidden = model.init_hidden()
        hidden, output = model(input, hidden)
        val, idx = output.max(1)
        predicted = decode_out(idx)
        if (expected != predicted):
            print("check : ", decode_inp(input), " -> expected: ", expected, "        predicted: ", predicted, "   *****")
            err_count += 1
        else:
            print("check : ", decode_inp(input), " -> expected: ", expected, "        predicted: ", predicted)
    return (err_count)

def evaluate_model(xdata, ydata, seqmax):
    xdata = simple_encode_strlist(xdata, seqmax, Inp_alphabet)
    ydata = simple_encode_strlist(ydata, seqmax, Out_alphabet)
    return evaluate_model_1(xdata, ydata)

################################################################################
def validation_phase():
    print("============================= validation inputs ===========================")
    validation_inputs, validation_outputs, seqmax = load_data_file('rnn3-train-data.txt')
    num_io_data = len(validation_inputs)
    if seqmax != Seq_max:
        print("seqmax mismatch", seqmax, Seq_max)
        sys.exit(1)
    seqmax = Seq_max

    errcount = evaluate_model(validation_inputs, validation_outputs, seqmax)
    val_accuracy = 100.0 * (num_io_data - errcount) / num_io_data

    if errcount > 0:
        print("VALIDATION FAILED:  errors: ", errcount, "accuracy:", val_accuracy)
    else:
        print("Validation Passed")
    return val_accuracy


################################################################################
def test_phase():
    print("============================= test inputs ===========================")
    test_inputs, test_outputs, seqmax = load_data_file('rnn3-test-data.txt')
    num_io_data = len(test_inputs)
    #if seqmax != Seq_max: #this could happen just due to randomness #todo
    #    print("WARN: seqmax mismatch")     ## possible to have diff seq max from the train data
    #    sys.exit(1)
    seqmax = Seq_max


    errcount = evaluate_model(test_inputs, test_outputs, seqmax)
    test_accuracy = 100.0 * (num_io_data - errcount) / num_io_data

    print("Testset size: ", len(test_inputs),"Test errors: ", errcount, "accuracy:", test_accuracy)
    return test_accuracy

################################################################################

########################################################
#Instantiate RNN model
#model = Model_RNN()
Rnn_type = '###'
model = Model_LSTM()
Rnn_type = model.Rnn_type

####################### Plotting code ##################

plt.ion()
plt_fig, plt_ax1 = plt.subplots()
plt_ax2 = plt_ax1.twinx()
plt_ax1.set_xlabel('epoch')
plt_ax1.set_ylabel('loss', color='red')
plt_ax2.set_ylabel('accuracy', color='blue')

txt = "Dataset: " + Arg_dataset_name + "\nrnn_type: "+ Rnn_type + "\nnum_layers: "+ str(num_layers) + "\nnum_io_samples: "+ str(Num_io_data) + "\nseq_max_len: "+ str(Seq_max)
txt += "\nBase_LR: " + str(learning_rate)

#plt_fig = plt.figure()
plt_fig.text(.5, .2, txt, ha='center', transform=plt_ax1.transAxes)
plt.pause(0.001)

plot_data = []
########################################################



################## Load trained model ###############
from pathlib import Path
modelimagefile = "rnn3model." + Imagesuffix + ".pt"
if Path(modelimagefile).is_file():
    # file exists
    model.load_state_dict(torch.load(modelimagefile))
    model.eval()
    print("=== Model was loaded from " + modelimagefile)

####################################################
Criterion = torch.nn.CrossEntropyLoss()
Optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
####################################################



# X is OH encoded
# Y is simple encoded
# this is the format needed by pytorch
Inputs = Variable(torch.Tensor(X_ohe))
Labels = Variable(torch.LongTensor(Y_data))

print("Input shape: ", Inputs.size())
print("Output shape: ", Labels.size())

final_train_accuracy, final_train_epoch = train_phase()

############ final plotting and logging ################
#plt.plot(plot_data)
#plt.waitforbuttonpress()
plt.savefig('rnn3-ttt.png',  bbox_inches='tight')
plt.show()
########################################################

val_accuracy = validation_phase()
test_accuracy = test_phase()

print("---------------------------------------------------------------------")
print("=== rnn_type:", Rnn_type,
        "num_layers:", num_layers,
        "num_io_samples (train): ", Num_io_data,
        "seq_max_len:", Seq_max)

print("\n Training end due to: ", Train_end_reason)
print("\n=== final_train_epoch:", final_train_epoch)
print("=== final_train_accuracy:  %1.2f%%       \n=== val_accuracy:  %1.2f%%        \n=== test_accuracy:  %1.2f%%\n"
        %  (final_train_accuracy, val_accuracy, test_accuracy))


######################### save trained model #######################
torch.save(model.state_dict(), modelimagefile)
print("=== Model was saved as " + modelimagefile)
####################################################################

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, random_state=1)
print("Train proportion: ",len(Xtrain)/len(X))
# Out:
# Train proportion:  0.7494824016563147

# %%
skmodel = LogisticRegression(class_weight='balanced')
#skmodel = LogisticRegression()
#skmodel = GaussianNB()
skmodel.fit(Xtrain, ytrain)                  
y_model = skmodel.predict(Xtest)   
ytrain_model = skmodel.predict(Xtrain)
print('Train accuracy: ',accuracy_score(ytrain, ytrain_model))
print('Test accuracy: ',accuracy_score(ytest, y_model))
print('F1 score: ',f1_score(ytest, y_model))
print('Matthews correlation coefficient: ',matthews_corrcoef(ytest,y_model))
# Out:
# Train accuracy:  0.9378453038674033
# Test accuracy:  0.6074380165289256
# F1 score:  0.6215139442231075
# Matthews correlation coefficient:  0.21430796208172556

# %% [markdown]
# Basic Logistic regression
# Train accuracy:  0.9972375690607734
# Test accuracy:  0.5867768595041323
# F1 score:  0.5934959349593496
# Matthews correlation coefficient:  0.17332786773245884

# %%
Xtrain.shape
# Out:
# (724, 512)

# %%
input_size = 512
output_size = 1
hidden_sizes = [128, 64]
model = nn.Sequential(nn.Linear(input_size, hidden_sizes[1]),
                      nn.ReLU(),
                      nn.Linear(hidden_sizes[1], output_size),
                      nn.Sigmoid())
print(model)
criterion = nn.MSELoss()

#CrossEntropyLoss() requires logits as the output and class labels as the target
# Out:
# Sequential(
#   (0): Linear(in_features=512, out_features=64, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=64, out_features=1, bias=True)
#   (3): Sigmoid()
# )

# %%
X = torch.from_numpy(X).float()
y = torch.from_numpy(y).float()
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, random_state=1)
print("Xtrain.shape: ",Xtrain.shape)
# Out:
# Xtrain.shape:  torch.Size([724, 512])

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.01) #weight_decay=1e-5
epochs = 10
for e in range(epochs):
    output = model(Xtrain)
    labels = ytrain.unsqueeze(1)
    optimizer.zero_grad()
    loss = criterion(output, labels)
    loss.backward()
    optimizer.step()
    if e % 2 == 0:
        print("Training loss: ",loss.item())
# Out:
# Training loss:  0.0852215439081192
# Training loss:  0.07720500975847244
# Training loss:  0.08967221528291702
# Training loss:  0.10272926092147827
# Training loss:  0.07113324850797653

# %%
predictions = output.detach().numpy()
predictions = np.where(predictions > 0.5, 1, 0)
predictions.sum()
# Out:
# 354

# %%
testoutput = model(Xtest)
testpredictions = testoutput.detach().numpy()
testpredictions = np.where(testpredictions > 0.5, 1, 0)
testpredictions.sum()
# Out:
# 100

# %%
print('Train accuracy: ',accuracy_score(predictions,ytrain))
print('Test accuracy: ',accuracy_score(testpredictions, ytest))
print('F1 score: ',f1_score(testpredictions, ytest))
print('Matthews: ',matthews_corrcoef(testpredictions, ytest))
# Out:
# Train accuracy:  0.9406077348066298
# Test accuracy:  0.5661157024793388
# F1 score:  0.5291479820627804
# Matthews:  0.13720062149495627

# %%
from __future__ import print_function
import argparse
import torch
import torch.utils.data
from torch import nn, optim
from torch.nn import functional as F
from torchvision import datasets, transforms
from torchvision.utils import save_image


parser = argparse.ArgumentParser(description='VAE MNIST Example')
parser.add_argument('--batch-size', type=int, default=128, metavar='N',
                    help='input batch size for training (default: 128)')
parser.add_argument('--epochs', type=int, default=10, metavar='N',
                    help='number of epochs to train (default: 10)')
parser.add_argument('--no-cuda', action='store_true', default=False,
                    help='disables CUDA training')
parser.add_argument('--seed', type=int, default=1, metavar='S',
                    help='random seed (default: 1)')
parser.add_argument('--log-interval', type=int, default=10, metavar='N',
                    help='how many batches to wait before logging training status')
args = parser.parse_args()
args.cuda = not args.no_cuda and torch.cuda.is_available()

torch.manual_seed(args.seed)

device = torch.device("cuda" if args.cuda else "cpu")

kwargs = {'num_workers': 1, 'pin_memory': True} if args.cuda else {}
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                   transform=transforms.ToTensor()),
    batch_size=args.batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.ToTensor()),
    batch_size=args.batch_size, shuffle=True, **kwargs)


class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()

        self.fc1 = nn.Linear(784, 400)
        self.fc21 = nn.Linear(400, 20)
        self.fc22 = nn.Linear(400, 20)
        self.fc3 = nn.Linear(20, 400)
        self.fc4 = nn.Linear(400, 784)

    def encode(self, x):
        h1 = F.relu(self.fc1(x))
        return self.fc21(h1), self.fc22(h1)

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return mu + eps*std

    def decode(self, z):
        h3 = F.relu(self.fc3(z))
        return torch.sigmoid(self.fc4(h3))

    def forward(self, x):
        mu, logvar = self.encode(x.view(-1, 784))
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar


model = VAE().to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)


# Reconstruction + KL divergence losses summed over all elements and batch
def loss_function(recon_x, x, mu, logvar):
    BCE = F.binary_cross_entropy(recon_x, x.view(-1, 784), reduction='sum')

    # see Appendix B from VAE paper:
    # Kingma and Welling. Auto-Encoding Variational Bayes. ICLR, 2014
    # https://arxiv.org/abs/1312.6114
    # 0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())

    return BCE + KLD


def train(epoch):
    model.train()
    train_loss = 0
    for batch_idx, (data, _) in enumerate(train_loader):
        data = data.to(device)
        optimizer.zero_grad()
        recon_batch, mu, logvar = model(data)
        loss = loss_function(recon_batch, data, mu, logvar)
        loss.backward()
        train_loss += loss.item()
        optimizer.step()
        if batch_idx % args.log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader),
                loss.item() / len(data)))

    print('====> Epoch: {} Average loss: {:.4f}'.format(
          epoch, train_loss / len(train_loader.dataset)))


def test(epoch):
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for i, (data, _) in enumerate(test_loader):
            data = data.to(device)
            recon_batch, mu, logvar = model(data)
            test_loss += loss_function(recon_batch, data, mu, logvar).item()
            if i == 0:
                n = min(data.size(0), 8)
                comparison = torch.cat([data[:n],
                                      recon_batch.view(args.batch_size, 1, 28, 28)[:n]])
                save_image(comparison.cpu(),
                         'results/reconstruction_' + str(epoch) + '.png', nrow=n)

    test_loss /= len(test_loader.dataset)
    print('====> Test set loss: {:.4f}'.format(test_loss))

if __name__ == "__main__":
    for epoch in range(1, args.epochs + 1):
        train(epoch)
        test(epoch)
        with torch.no_grad():
            sample = torch.randn(64, 20).to(device)
            sample = model.decode(sample).cpu()
            save_image(sample.view(64, 1, 28, 28),
                       'results/sample_' + str(epoch) + '.png')

# %%
print("hello")
# Out:
# hello
